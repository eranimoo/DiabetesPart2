# %%
#To stop getting warnings:
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np

#Here, to be able to apply to_datetime function, there was unclear entries in Time column
#All of them (38 items) have been deleted. These are the ones that I assigned big values while finding TimeStamp columns.
#I just deleted the items from .dat-Time-Added file.

data = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Data_Mining\\.dat-Time-Added.txt")

#When we check the types of the data frame, Value column's type is object.
#To groupby it, we need to convert it into numeric. But at first, we need to get rid off meaningless values
data["Value"]=data["Value"].replace(["0''","0Hi","3A","0Lo",np.nan],0)
data["Value"]=pd.to_numeric(data["Value"])


data=data.sort_values(["User ID", "Time_Stamp"],ascending = (True,True))
data.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Data_Mining\\Value-Replaced.txt", index=False )

count = 1
for i in range(1,71):
    dataseperate=data[data["User ID"].isin([i])]
    dataseperate["Index"]=dataseperate.index
    dataseperate.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(count) + ".txt", index=False )
    count=count+1

# %%
#Average of all Blood sugar levels up to that date.
#Before groupbying according to the date, there were some mistaken entries like 31-06.
#There is no 31st day in June. So, before starting, we converted it to 30 June by hand.

for i in range(1,71):
    average=0
    sum=0
    count=1
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        if (code== 48) | (code == 57)|(code== 58) | (code == 59)|(code== 60) | (code == 61)|(code== 62) | (code == 63)|(code== 64):
            sum=sum+value
            average=round(sum/count,2)
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    seri=pd.Series(liste)
    datapatient["Feature1"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all Blood sugar levels up to that date.
#Since 48 and 57 are related, they are removed.

for i in range(1,71):
    average=0
    sum=0
    count=1
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        if (code== 58) | (code == 59)|(code== 60) | (code == 61)|(code== 62) | (code == 63)|(code== 64):
            sum=sum+value
            average=round(sum/count,2)
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    seri=pd.Series(liste)
    datapatient["Feature1_1"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of Unspecified Blood sugar levels up to that date.
for i in range(1,71):
    average=0
    sum=0
    count=1

    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        if(code== 48) | (code == 57):
            sum=sum+value
            average=round(sum/count,2)
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    seri=pd.Series(liste)
    datapatient["Feature2"]=seri
    print(datapatient[["Value","Feature2","Code"]].head(50))
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )
# Out:
#     Value  Feature2  Code
# 0    13.0       NaN    34
# 1     9.0       NaN    33
# 2   100.0       NaN    58
# 3   119.0       NaN    62
# 4     7.0       NaN    33
# 5   123.0       NaN    48
# 6    13.0    123.00    34
# 7    10.0    123.00    33
# 8   216.0    123.00    58
# 9     2.0    123.00    33
# 10  211.0    123.00    62
# 11    7.0    123.00    33
# 12   11.0    123.00    33
# 13  257.0    123.00    58
# 14   13.0    123.00    34
# 15  129.0    123.00    62
# 16    7.0    123.00    33
# 17   14.0    123.00    34
# 18  239.0    123.00    58
# 19   10.0    123.00    33
# 20    4.0    123.00    33
# 21  129.0    123.00    62
# 22  340.0    123.00    48
# 23    5.0    231.50    33
# 24    9.0    231.50    33
# 25   67.0    231.50    58
# 26   14.0    231.50    34
# 27    4.0    231.50    33
# 28    7.0    231.50    33
# 29  206.0    231.50    62
# 30  288.0    231.50    48
# 31    2.0    250.33    33
# 32   77.0    250.33    58
# 33   14.0    250.33    34
# 34    9.0    250.33    33
# 35    5.0    250.33    33
# 36    7.0    250.33    33
# 37  228.0    250.33    62
# 38   14.0    250.33    34
# 39   10.0    250.33    33
# 40  259.0    250.33    58
# 41    8.0    250.33    33
# 42  256.0    250.33    62
# 43   10.0    250.33    33
# 44  109.0    250.33    58
# 45   14.0    250.33    34
# 46   96.0    250.33    62
# 47    7.0    250.33    33
# 48  200.0    250.33    48
# 49   14.0    237.75    34
#     Value  Feature2  Code
# 0    10.0       NaN    33
# 1   149.0       NaN    58
# 2   116.0       NaN    60
# 3     4.0       NaN    33
# 4    10.0       NaN    33
# 5   304.0       NaN    62
# 6    63.0       NaN    48
# 7    14.0     63.00    33
# 8    10.0     63.00    33
# 9   171.0     63.00    58
# 10    4.0     63.00    33
# 11  148.0     63.00    60
# 12   10.0     63.00    33
# 13  115.0     63.00    62
# 14   14.0     63.00    33
# 15  130.0     63.00    48
# 16  220.0     96.50    58
# 17   10.0     96.50    33
# 18   10.0     96.50    33
# 19  125.0     96.50    62
# 20  110.0     96.50    48
# 21   14.0    101.00    33
# 22  288.0    101.00    58
# 23   10.0    101.00    33
# 24    4.0    101.00    33
# 25  284.0    101.00    60
# 26   10.0    101.00    33
# 27   47.0    101.00    62
# 28   14.0    101.00    33
# 29  288.0    101.00    48
# 30  201.0    147.75    58
# 31   10.0    147.75    33
# 32  141.0    147.75    60
# 33    4.0    147.75    33
# 34  170.0    147.75    62
# 35   10.0    147.75    33
# 36  131.0    147.75    48
# 37   14.0    144.40    33
# 38  206.0    144.40    58
# 39   10.0    144.40    33
# 40  168.0    144.40    60
# 41    4.0    144.40    33
# 42  176.0    144.40    62
# 43   10.0    144.40    33
# 44  263.0    144.40    48
# 45   14.0    164.17    33
# 46   12.0    164.17    33
# 47  344.0    164.17    58
# 48    6.0    164.17    33
# 49  248.0    164.17    60
#     Value  Feature2  Code
# 0   202.0       NaN    58
# 1     9.0       NaN    35
# 2     4.0       NaN    33
# 3   134.0       NaN    60
# 4   100.0       NaN    62
# 5     8.0       NaN    35
# 6   156.0       NaN    64
# 7    92.0       NaN    58
# 8     3.0       NaN    33
# 9     9.0       NaN    35
# 10  151.0       NaN    61
# 11  238.0       NaN    62
# 12    0.0       NaN    67
# 13    1.0       NaN    33
# 14    8.0       NaN    35
# 15  180.0       NaN    63
# 16  101.0       NaN    58
# 17    9.0       NaN    35
# 18    3.0       NaN    33
# 19   65.0       NaN    60
# 20  197.0       NaN    62
# 21    1.0       NaN    33
# 22    8.0       NaN    35
# 23  102.0       NaN    63
# 24  124.0       NaN    58
# 25    9.0       NaN    35
# 26    3.0       NaN    33
# 27  178.0       NaN    61
# 28  175.0       NaN    62
# 29    1.0       NaN    33
# 30    8.0       NaN    35
# 31  119.0       NaN    64
# 32   92.0       NaN    58
# 33    3.0       NaN    33
# 34    9.0       NaN    35
# 35   84.0       NaN    60
# 36  217.0       NaN    62
# 37    8.0       NaN    35
# 38    1.0       NaN    33
# 39  161.0       NaN    63
# 40   70.0       NaN    58
# 41    9.0       NaN    35
# 42    3.0       NaN    33
# 43  192.0       NaN    61
# 44  202.0       NaN    62
# 45    1.0       NaN    33
# 46    8.0       NaN    35
# 47  100.0       NaN    64
# 48   96.0       NaN    58
# 49    9.0       NaN    35
#     Value  Feature2  Code
# 0   104.0       NaN    62
# 1     8.0       NaN    35
# 2    94.0       NaN    64
# 3    83.0       NaN    58
# 4     3.0       NaN    33
# 5     9.0       NaN    35
# 6   295.0       NaN    63
# 7     1.0       NaN    33
# 8     8.0       NaN    35
# 9    50.0       NaN    64
# 10   80.0       NaN    58
# 11    3.0       NaN    33
# 12    8.0       NaN    35
# 13    0.0       NaN    65
# 14  278.0       NaN    62
# 15    2.0       NaN    33
# 16    8.0       NaN    35
# 17  116.0       NaN    64
# 18  149.0       NaN    58
# 19    9.0       NaN    35
# 20    3.0       NaN    33
# 21  194.0       NaN    60
# 22    0.0       NaN    67
# 23   81.0       NaN    62
# 24    8.0       NaN    35
# 25  182.0       NaN    64
# 26  102.0       NaN    58
# 27    3.0       NaN    33
# 28    9.0       NaN    35
# 29   41.0       NaN    60
# 30  291.0       NaN    63
# 31    1.0       NaN    33
# 32    8.0       NaN    35
# 33  200.0       NaN    63
# 34  298.0       NaN    58
# 35    0.0       NaN    72
# 36    4.0       NaN    33
# 37    9.0       NaN    35
# 38   38.0       NaN    60
# 39  120.0       NaN    62
# 40    8.0       NaN    35
# 41  159.0       NaN    64
# 42  158.0       NaN    58
# 43    3.0       NaN    33
# 44    9.0       NaN    35
# 45   46.0       NaN    60
# 46  241.0       NaN    63
# 47    1.0       NaN    33
# 48    8.0       NaN    35
# 49   56.0       NaN    64
#     Value  Feature2  Code
# 0   226.0       NaN    62
# 1     8.0       NaN    34
# 2     1.0       NaN    33
# 3   154.0       NaN    64
# 4    66.0       NaN    58
# 5    10.0       NaN    34
# 6     2.0       NaN    33
# 7   136.0       NaN    60
# 8     0.0       NaN    67
# 9   319.0       NaN    62
# 10    0.0       NaN    67
# 11    2.0       NaN    33
# 12    8.0       NaN    34
# 13  227.0       NaN    64
# 14  192.0       NaN    58
# 15    3.0       NaN    33
# 16    9.0       NaN    34
# 17  115.0       NaN    60
# 18  287.0       NaN    62
# 19    1.0       NaN    33
# 20    8.0       NaN    34
# 21  202.0       NaN    64
# 22  123.0       NaN    58
# 23    9.0       NaN    34
# 24    3.0       NaN    33
# 25   63.0       NaN    60
# 26  301.0       NaN    62
# 27    8.0       NaN    34
# 28    1.0       NaN    33
# 29  239.0       NaN    63
# 30  118.0       NaN    58
# 31    9.0       NaN    34
# 32    3.0       NaN    33
# 33  100.0       NaN    60
# 34  238.0       NaN    62
# 35    8.0       NaN    34
# 36    1.0       NaN    33
# 37   80.0       NaN    64
# 38   60.0       NaN    58
# 39    3.0       NaN    33
# 40    9.0       NaN    34
# 41   85.0       NaN    60
# 42  341.0       NaN    62
# 43    1.0       NaN    33
# 44    8.0       NaN    34
# 45  137.0       NaN    64
# 46   92.0       NaN    58
# 47    9.0       NaN    34
# 48    3.0       NaN    33
# 49   57.0       NaN    60
#     Value  Feature2  Code
# 0     8.0       NaN    33
# 1   161.0       NaN    58
# 2    18.0       NaN    34
# 3   210.0       NaN    60
# 4     3.0       NaN    33
# 5    18.0       NaN    34
# 6     8.0       NaN    33
# 7   170.0       NaN    58
# 8   126.0       NaN    60
# 9     3.0       NaN    33
# 10  210.0       NaN    48
# 11    8.0     210.0    33
# 12  210.0     210.0    58
# 13   18.0     210.0    34
# 14    3.0     210.0    33
# 15  155.0     210.0    60
# 16  161.0     210.0    62
# 17    7.0     210.0    33
# 18    8.0     210.0    33
# 19   18.0     210.0    34
# 20  288.0     210.0    58
# 21  182.0     210.0    60
# 22    4.0     210.0    33
# 23  224.0     210.0    62
# 24    8.0     210.0    33
# 25  168.0     210.0    58
# 26    7.0     210.0    33
# 27   18.0     210.0    34
# 28  101.0     210.0    60
# 29    3.0     210.0    33
# 30    8.0     210.0    33
# 31  259.0     210.0    62
# 32   18.0     210.0    34
# 33    7.0     210.0    33
# 34  192.0     210.0    58
# 35    3.0     210.0    33
# 36  184.0     210.0    60
# 37  239.0     210.0    62
# 38    8.0     210.0    33
# 39    2.0     210.0    33
# 40  320.0     210.0    48
# 41  192.0     265.0    58
# 42    8.0     265.0    33
# 43   18.0     265.0    34
# 44    4.0     265.0    33
# 45  155.0     265.0    60
# 46   10.0     265.0    33
# 47  221.0     265.0    62
# 48   18.0     265.0    34
# 49    7.0     265.0    33
#     Value  Feature2  Code
# 0   207.0       NaN    48
# 1     7.0    207.00    33
# 2   187.0    207.00    58
# 3    18.0    207.00    34
# 4   230.0    207.00    60
# 5     4.0    207.00    33
# 6   274.0    207.00    62
# 7    10.0    207.00    33
# 8   259.0    207.00    58
# 9     8.0    207.00    33
# 10   18.0    207.00    34
# 11  192.0    207.00    60
# 12    4.0    207.00    33
# 13  197.0    207.00    62
# 14    6.0    207.00    33
# 15  189.0    207.00    48
# 16  202.0    198.00    58
# 17   18.0    198.00    34
# 18    8.0    198.00    33
# 19  163.0    198.00    60
# 20    4.0    198.00    33
# 21  218.0    198.00    62
# 22   10.0    198.00    33
# 23  147.0    198.00    48
# 24  138.0    181.00    58
# 25    6.0    181.00    33
# 26   18.0    181.00    34
# 27   64.0    181.00    60
# 28    3.0    181.00    33
# 29   10.0    181.00    33
# 30  224.0    181.00    62
# 31  230.0    181.00    48
# 32   18.0    193.25    34
# 33    6.0    193.25    33
# 34  149.0    193.25    58
# 35    4.0    193.25    33
# 36   86.0    193.25    62
# 37   10.0    193.25    33
# 38  182.0    193.25    48
# 39   97.0    191.00    58
# 40    5.0    191.00    33
# 41   18.0    191.00    34
# 42  170.0    191.00    60
# 43    4.0    191.00    33
# 44  218.0    191.00    62
# 45   10.0    191.00    33
# 46  101.0    191.00    48
# 47   18.0    176.00    34
# 48    7.0    176.00    33
# 49  199.0    176.00    58
#     Value  Feature2  Code
# 0   100.0       NaN    60
# 1   190.0       NaN    62
# 2   124.0       NaN    62
# 3   222.0       NaN    58
# 4   339.0       NaN    60
# 5     0.0       NaN    68
# 6    71.0       NaN    60
# 7    72.0       NaN    61
# 8   193.0       NaN    62
# 9    57.0       NaN    64
# 10    0.0       NaN    65
# 11  240.0       NaN    58
# 12  236.0       NaN    60
# 13  224.0       NaN    64
# 14  121.0       NaN    58
# 15    0.0       NaN    65
# 16   73.0       NaN    58
# 17    0.0       NaN    67
# 18   83.0       NaN    60
# 19  168.0       NaN    58
# 20    0.0       NaN    65
# 21   65.0       NaN    58
# 22   69.0       NaN    58
# 23  210.0       NaN    58
# 24  231.0       NaN    62
# 25  159.0       NaN    64
# 26   60.0       NaN    58
# 27    0.0       NaN    65
# 28    0.0       NaN    67
# 29  236.0       NaN    58
# 30  103.0       NaN    60
# 31    0.0       NaN    67
# 32   72.0       NaN    60
# 33  269.0       NaN    62
# 34  329.0       NaN    62
# 35  278.0       NaN    58
# 36  218.0       NaN    60
# 37   87.0       NaN    62
# 38   87.0       NaN    63
# 39  134.0       NaN    58
# 40  251.0       NaN    60
# 41  171.0       NaN    58
# 42  187.0       NaN    62
# 43    0.0       NaN    69
# 44    0.0       NaN    67
# 45   82.0       NaN    62
# 46  188.0       NaN    64
# 47   57.0       NaN    58
# 48    0.0       NaN    65
# 49  268.0       NaN    58
#     Value  Feature2  Code
# 0   213.0       NaN    62
# 1    13.0       NaN    33
# 2   102.0       NaN    64
# 3     5.0       NaN    33
# 4    15.0       NaN    34
# 5   151.0       NaN    58
# 6     8.0       NaN    33
# 7   350.0       NaN    60
# 8    10.0       NaN    33
# 9    93.0       NaN    62
# 10    7.0       NaN    33
# 11  103.0       NaN    64
# 12    5.0       NaN    33
# 13   15.0       NaN    34
# 14   83.0       NaN    58
# 15    7.0       NaN    33
# 16   31.0       NaN    60
# 17    0.0       NaN    72
# 18  324.0       NaN    62
# 19   10.0       NaN    33
# 20  145.0       NaN    64
# 21    5.0       NaN    33
# 22   15.0       NaN    34
# 23   45.0       NaN    58
# 24    6.0       NaN    33
# 25  335.0       NaN    60
# 26   10.0       NaN    33
# 27  259.0       NaN    63
# 28    8.0       NaN    33
# 29  240.0       NaN    64
# 30    6.0       NaN    33
# 31   15.0       NaN    34
# 32  132.0       NaN    58
# 33   97.0       NaN    60
# 34  270.0       NaN    62
# 35   10.0       NaN    33
# 36   72.0       NaN    64
# 37    4.0       NaN    33
# 38   14.0       NaN    34
# 39  309.0       NaN    58
# 40   10.0       NaN    33
# 41  181.0       NaN    60
# 42    9.0       NaN    33
# 43   44.0       NaN    62
# 44  172.0       NaN    64
# 45   15.0       NaN    34
# 46    5.0       NaN    33
# 47   82.0       NaN    58
# 48    7.0       NaN    33
# 49  284.0       NaN    60
#     Value  Feature2  Code
# 0     8.0       NaN    34
# 1     2.0       NaN    33
# 2   161.0       NaN    58
# 3    72.0       NaN    60
# 4   270.0       NaN    62
# 5   238.0       NaN    48
# 6     2.0     238.0    33
# 7     8.0     238.0    34
# 8   147.0     238.0    58
# 9   176.0     238.0    60
# 10  197.0     238.0    62
# 11    2.0     238.0    33
# 12    5.0     238.0    34
# 13    3.0     238.0    33
# 14    8.0     238.0    34
# 15  245.0     238.0    58
# 16  294.0     238.0    60
# 17    3.0     238.0    33
# 18    5.0     238.0    34
# 19  265.0     238.0    62
# 20  302.0     238.0    58
# 21    3.0     238.0    33
# 22    8.0     238.0    34
# 23   73.0     238.0    60
# 24  168.0     238.0    62
# 25    2.0     238.0    33
# 26    4.0     238.0    34
# 27    7.0     238.0    34
# 28  161.0     238.0    58
# 29    2.0     238.0    33
# 30  147.0     238.0    60
# 31    2.0     238.0    33
# 32  216.0     238.0    62
# 33    3.0     238.0    34
# 34  150.0     238.0    58
# 35    2.0     238.0    33
# 36    7.0     238.0    34
# 37  147.0     238.0    60
# 38    3.0     238.0    34
# 39    3.0     238.0    33
# 40  249.0     238.0    62
# 41    2.0     238.0    33
# 49  223.0       NaN    60
#     Value  Feature2  Code
# 0    34.0       NaN    34
# 1    11.0       NaN    33
# 2     0.0       NaN    67
# 3    60.0       NaN    60
# 4    75.0       NaN    64
# 5    59.0       NaN    62
# 6     2.0       NaN    33
# 7     3.0       NaN    34
# 8     0.0       NaN    65
# 9    92.0       NaN    64
# 10    6.0       NaN    34
# 11   80.0       NaN    58
# 12    8.0       NaN    33
# 13   33.0       NaN    34
# 14   46.0       NaN    60
# 15    0.0       NaN    65
# 16  151.0       NaN    64
# 17    0.0       NaN    67
# 18   35.0       NaN    62
# 19    0.0       NaN    69
# 20    3.0       NaN    34
# 21    2.0       NaN    33
# 22    0.0       NaN    65
# 23  246.0       NaN    64
# 24    2.0       NaN    33
# 25    6.0       NaN    34
# 26    0.0       NaN    67
# 27  142.0       NaN    58
# 28    8.0       NaN    33
# 29   33.0       NaN    34
# 30   48.0       NaN    60
# 31    0.0       NaN    65
# 32  189.0       NaN    62
# 33    4.0       NaN    34
# 34    3.0       NaN    33
# 35    0.0       NaN    67
# 36    0.0       NaN    71
# 37  338.0       NaN    64
# 38    6.0       NaN    34
# 39    0.0       NaN    69
# 40    2.0       NaN    33
# 41  197.0       NaN    58
# 42    9.0       NaN    33
# 43   33.0       NaN    34
# 44   85.0       NaN    60
# 45   40.0       NaN    62
# 46    0.0       NaN    65
# 47    4.0       NaN    34
# 48    0.0       NaN    71
# 49    2.0       NaN    33
#     Value  Feature2  Code
# 0   163.0       NaN    62
# 1     0.0       NaN    69
# 2     0.0       NaN    66
# 3    87.0       NaN    64
# 4     0.0       NaN    70
# 5   128.0       NaN    58
# 6     0.0       NaN    66
# 7    56.0       NaN    62
# 8     2.0       NaN    33
# 9     0.0       NaN    69
# 10    0.0       NaN    66
# 11    3.0       NaN    34
# 12  157.0       NaN    64
# 13    6.0       NaN    34
# 14   54.0       NaN    58
# 15    0.0       NaN    66
# 16    0.0       NaN    65
# 17    4.0       NaN    33
# 18   31.0       NaN    34
# 19   56.0       NaN    64
# 20    4.0       NaN    34
# 21    0.0       NaN    69
# 22  332.0       NaN    58
# 23   31.0       NaN    34
# 24    8.0       NaN    33
# 25    0.0       NaN    66
# 26    0.0       NaN    67
# 27  179.0       NaN    62
# 28    3.0       NaN    34
# 29    3.0       NaN    33
# 30    0.0       NaN    67
# 31    0.0       NaN    66
# 32    0.0       NaN    69
# 33  243.0       NaN    58
# 34    0.0       NaN    66
# 35   31.0       NaN    34
# 36    0.0       NaN    72
# 37    8.0       NaN    33
# 38  142.0       NaN    64
# 39    6.0       NaN    34
# 40    0.0       NaN    70
# 41  102.0       NaN    58
# 42    5.0       NaN    33
# 43   31.0       NaN    34
# 44    0.0       NaN    66
# 45    0.0       NaN    69
# 46   92.0       NaN    62
# 47    3.0       NaN    34
# 48    2.0       NaN    33
# 49    0.0       NaN    69
#     Value  Feature2  Code
# 0    31.0       NaN    34
# 1     8.0       NaN    33
# 2     0.0       NaN    67
# 3   275.0       NaN    58
# 4     9.0       NaN    33
# 5    31.0       NaN    34
# 6    50.0       NaN    58
# 7     4.0       NaN    33
# 8    30.0       NaN    34
# 9    96.0       NaN    64
# 10    6.0       NaN    34
# 11  138.0       NaN    58
# 12    5.0       NaN    33
# 13   31.0       NaN    34
# 14   61.0       NaN    62
# 15    3.0       NaN    34
# 16    0.0       NaN    66
# 17    2.0       NaN    33
# 18   71.0       NaN    64
# 19    5.0       NaN    34
# 20   72.0       NaN    58
# 21   31.0       NaN    34
# 22    5.0       NaN    33
# 23  330.0       NaN    58
# 24   10.0       NaN    33
# 25   31.0       NaN    34
# 26    0.0       NaN    67
# 27  205.0       NaN    58
# 28   31.0       NaN    34
# 29    7.0       NaN    33
# 30   49.0       NaN    58
# 31    4.0       NaN    33
# 32   31.0       NaN    34
# 33  168.0       NaN    59
# 34  338.0       NaN    58
# 35   10.0       NaN    33
# 36   31.0       NaN    34
# 37    0.0       NaN    67
# 38   38.0       NaN    64
# 39    5.0       NaN    34
# 40    0.0       NaN    65
# 41  269.0       NaN    58
# 42    9.0       NaN    33
# 43   31.0       NaN    34
# 44    0.0       NaN    67
# 45  253.0       NaN    62
# 46    0.0       NaN    71
# 47    3.0       NaN    34
# 48    5.0       NaN    33
# 49   89.0       NaN    64
#     Value  Feature2  Code
# 0    31.0       NaN    34
# 1   179.0       NaN    62
# 2     3.0       NaN    33
# 3     3.0       NaN    34
# 4    84.0       NaN    58
# 5    31.0       NaN    34
# 6     5.0       NaN    33
# 7   292.0       NaN    58
# 8     9.0       NaN    33
# 9    31.0       NaN    34
# 10  229.0       NaN    58
# 11    0.0       NaN    67
# 12   31.0       NaN    34
# 13    9.0       NaN    33
# 14  177.0       NaN    58
# 15   31.0       NaN    34
# 16    5.0       NaN    33
# 17  284.0       NaN    62
# 18    0.0       NaN    70
# 19    0.0       NaN    67
# 20    6.0       NaN    33
# 21    3.0       NaN    34
# 22  105.0       NaN    58
# 23   31.0       NaN    34
# 24    5.0       NaN    33
# 25  138.0       NaN    58
# 26   31.0       NaN    34
# 27    5.0       NaN    33
# 28  237.0       NaN    64
# 29    6.0       NaN    34
# 30    4.0       NaN    33
# 31   47.0       NaN    58
# 32    3.0       NaN    33
# 33   31.0       NaN    34
# 34    0.0       NaN    65
# 35  170.0       NaN    64
# 36    6.0       NaN    34
# 37   23.0       NaN    58
# 38    3.0       NaN    33
# 39   30.0       NaN    34
# 40    0.0       NaN    65
# 41  176.0       NaN    58
# 42   31.0       NaN    34
# 43    6.0       NaN    33
# 44  348.0       NaN    58
# 45    0.0       NaN    67
# 46   31.0       NaN    34
# 47   10.0       NaN    33
# 48  289.0       NaN    58
# 49   31.0       NaN    34
#     Value  Feature2  Code
# 0     0.0       NaN    70
# 1     0.0       NaN    65
# 2   119.0       NaN    58
# 3     2.0       NaN    33
# 4    17.0       NaN    34
# 5     0.0       NaN    65
# 6    95.0       NaN    57
# 7     0.0      95.0    65
# 8     0.0      95.0    69
# 9   190.0      95.0    62
# 10    2.0      95.0    33
# 11    0.0      95.0    69
# 12  112.0      95.0    64
# 13   89.0      95.0    58
# 14   17.0      95.0    34
# 15    1.0      95.0    33
# 16  179.0      95.0    60
# 17    1.0      95.0    33
# 18   48.0      95.0    62
# 19  280.0      95.0    64
# 20    2.0      95.0    33
# 21    2.0      95.0    33
# 22    9.0      95.0    34
# 23   67.0      95.0    58
# 24    1.0      95.0    33
# 25   17.0      95.0    34
# 26   65.0      95.0    60
# 27  251.0      95.0    62
# 28    2.0      95.0    33
# 29   46.0      95.0    64
# 30    9.0      95.0    34
# 31   79.0      95.0    58
# 32   17.0      95.0    34
# 33    1.0      95.0    33
# 34   72.0      95.0    60
# 35  149.0      95.0    62
# 36  270.0      95.0    64
# 37    2.0      95.0    33
# 38    9.0      95.0    34
# 39    0.0      95.0    65
# 40   63.0      95.0    57
# 41  164.0      79.0    58
# 42   17.0      79.0    34
# 43    2.0      79.0    33
# 44   55.0      79.0    60
# 45   74.0      79.0    62
# 46  251.0      79.0    64
# 47    9.0      79.0    34
# 48    2.0      79.0    33
# 49   48.0      79.0    57
#     Value  Feature2  Code
# 0    15.0       NaN    34
# 1   141.0       NaN    60
# 2   280.0       NaN    62
# 3     2.0       NaN    33
# 4   308.0       NaN    64
# 5     3.0       NaN    33
# 6     0.0       NaN    71
# 7     9.0       NaN    34
# 8    50.0       NaN    58
# 9    15.0       NaN    34
# 10    0.0       NaN    70
# 11   59.0       NaN    60
# 12  228.0       NaN    62
# 13    2.0       NaN    33
# 14  146.0       NaN    64
# 15    9.0       NaN    34
# 16  292.0       NaN    58
# 17    3.0       NaN    33
# 18   15.0       NaN    34
# 19  134.0       NaN    60
# 20  167.0       NaN    62
# 21    2.0       NaN    33
# 22    0.0       NaN    70
# 23   99.0       NaN    64
# 24    9.0       NaN    34
# 25   77.0       NaN    58
# 26   15.0       NaN    34
# 27  174.0       NaN    60
# 28    1.0       NaN    33
# 29   95.0       NaN    62
# 30  206.0       NaN    64
# 31    0.0       NaN    70
# 32    9.0       NaN    34
# 33    2.0       NaN    33
# 34   92.0       NaN    58
# 35   15.0       NaN    34
# 36    1.0       NaN    33
# 37   98.0       NaN    60
# 38  174.0       NaN    62
# 39    2.0       NaN    33
# 40  325.0       NaN    64
# 41    3.0       NaN    33
# 42    9.0       NaN    34
# 43   90.0       NaN    58
# 44    1.0       NaN    33
# 45   15.0       NaN    34
# 46  210.0       NaN    60
# 47    2.0       NaN    33
# 48  151.0       NaN    62
# 49    2.0       NaN    33
#     Value  Feature2  Code
# 0     2.0       NaN    33
# 1   122.0       NaN    64
# 2     9.0       NaN    34
# 3    73.0       NaN    58
# 4     1.0       NaN    33
# 5    15.0       NaN    34
# 6   224.0       NaN    60
# 7     2.0       NaN    33
# 8   163.0       NaN    62
# 9     2.0       NaN    33
# 10    0.0       NaN    70
# 11  164.0       NaN    64
# 12    9.0       NaN    34
# 13    1.0       NaN    33
# 14  192.0       NaN    58
# 15    2.0       NaN    33
# 16   15.0       NaN    34
# 17  157.0       NaN    60
# 18  124.0       NaN    62
# 19    2.0       NaN    33
# 20   56.0       NaN    64
# 21    0.0       NaN    70
# 22    9.0       NaN    34
# 23  162.0       NaN    58
# 24   15.0       NaN    34
# 25    2.0       NaN    33
# 26   96.0       NaN    60
# 27  114.0       NaN    62
# 28  138.0       NaN    64
# 29    9.0       NaN    34
# 30  213.0       NaN    58
# 31   15.0       NaN    34
# 32    2.0       NaN    33
# 33   70.0       NaN    60
# 34  161.0       NaN    62
# 35    2.0       NaN    33
# 36  164.0       NaN    64
# 37    9.0       NaN    34
# 38    1.0       NaN    33
# 39    0.0       NaN    65
# 40  285.0       NaN    58
# 41   15.0       NaN    34
# 42    2.0       NaN    33
# 43  102.0       NaN    60
# 44   98.0       NaN    57
# 45    2.0      98.0    33
# 46    0.0      98.0    70
# 47   96.0      98.0    64
# 48    1.0      98.0    34
# 49    8.0      98.0    34
#     Value  Feature2  Code
# 0    24.0       NaN    34
# 1     6.0       NaN    33
# 2   223.0       NaN    58
# 3     8.0       NaN    33
# 4   260.0       NaN    60
# 5    94.0       NaN    62
# 6     9.0       NaN    33
# 7     4.0       NaN    33
# 8    24.0       NaN    34
# 9   158.0       NaN    58
# 10    7.0       NaN    33
# 11  198.0       NaN    60
# 12  250.0       NaN    62
# 13   12.0       NaN    33
# 14  320.0       NaN    58
# 15    8.0       NaN    33
# 16   24.0       NaN    34
# 17  188.0       NaN    60
# 18    5.0       NaN    33
# 19  109.0       NaN    62
# 20   10.0       NaN    33
# 21    1.0       NaN    33
# 22  186.0       NaN    48
# 23   24.0     186.0    34
# 24    5.0     186.0    33
# 25  233.0     186.0    58
# 26  270.0     186.0    60
# 27    8.0     186.0    33
# 28   10.0     186.0    33
# 29  127.0     186.0    62
# 30  249.0     186.0    58
# 31    6.0     186.0    33
# 32   24.0     186.0    34
# 33    7.0     186.0    33
# 34  217.0     186.0    60
# 35  157.0     186.0    62
# 36  152.0     186.0    58
# 37    4.0     186.0    33
# 38   24.0     186.0    34
# 39    7.0     186.0    33
# 40  200.0     186.0    60
# 41   12.0     186.0    33
# 42  264.0     186.0    62
# 43   24.0     186.0    34
# 44  220.0     186.0    58
# 45    6.0     186.0    33
# 46    9.0     186.0    33
# 47  297.0     186.0    60
# 48  156.0     186.0    62
# 49   11.0     186.0    33
#     Value  Feature2  Code
# 0    18.0       NaN    34
# 1    10.0       NaN    33
# 2   125.0       NaN    58
# 3   193.0       NaN    60
# 4    10.0       NaN    33
# 5   156.0       NaN    62
# 6    12.0       NaN    33
# 7    18.0       NaN    34
# 8   281.0       NaN    58
# 9    14.0       NaN    33
# 10   18.0       NaN    34
# 11  113.0       NaN    60
# 12   10.0       NaN    33
# 13   68.0       NaN    62
# 14   18.0       NaN    34
# 15   12.0       NaN    33
# 16  145.0       NaN    48
# 17   18.0    145.00    34
# 18  151.0    145.00    58
# 19   10.0    145.00    33
# 20  122.0    145.00    60
# 21   10.0    145.00    33
# 22   91.0    145.00    62
# 23   12.0    145.00    33
# 24   18.0    145.00    34
# 25  160.0    145.00    48
# 26  153.0    152.50    58
# 48  103.0     87.83    58
# 49    6.0     87.83    33
#     Value  Feature2  Code
# 0    16.0       NaN    34
# 1     6.0       NaN    33
# 2   179.0       NaN    58
# 3   117.0       NaN    60
# 4     4.0       NaN    33
# 5    63.0       NaN    62
# 6     6.0       NaN    33
# 7    92.0       NaN    48
# 8    16.0     92.00    34
# 9     6.0     92.00    33
# 10  142.0     92.00    58
# 11  154.0     92.00    60
# 12    4.0     92.00    33
# 13    6.0     92.00    33
# 14  110.0     92.00    62
# 15  132.0     92.00    48
# 16  126.0    112.00    58
# 17    6.0    112.00    33
# 18   16.0    112.00    34
# 19   80.0    112.00    60
# 20    4.0    112.00    33
# 21    6.0    112.00    33
# 22  167.0    112.00    62
# 23  256.0    112.00    48
# 24  300.0    160.00    58
# 25    6.0    160.00    33
# 26   16.0    160.00    34
# 27  147.0    160.00    60
# 28    4.0    160.00    33
# 29   92.0    160.00    62
# 30    6.0    160.00    33
# 31  182.0    160.00    48
# 32  282.0    165.50    58
# 33   16.0    165.50    34
# 34    6.0    165.50    33
# 35  180.0    165.50    60
# 36    4.0    165.50    33
# 37  172.0    165.50    62
# 38    6.0    165.50    33
# 39  134.0    165.50    48
# 40    6.0    159.20    33
# 41   16.0    159.20    34
# 42  283.0    159.20    58
# 43  240.0    159.20    60
# 44    4.0    159.20    33
# 45  192.0    159.20    62
# 46    6.0    159.20    33
# 47  154.0    159.20    48
# 48  247.0    158.33    58
# 49    6.0    158.33    33
#     Value  Feature2  Code
# 0     7.0       NaN    33
# 1   136.0       NaN    58
# 2    18.0       NaN    34
# 3    62.0       NaN    60
# 4     4.0       NaN    33
# 5     6.0       NaN    33
# 6    81.0       NaN    62
# 7   102.0       NaN    48
# 8    18.0    102.00    34
# 9    97.0    102.00    58
# 10    7.0    102.00    33
# 11    4.0    102.00    33
# 12  132.0    102.00    60
# 13    6.0    102.00    33
# 14  144.0    102.00    62
# 15  162.0    102.00    48
# 16  183.0    132.00    58
# 17    7.0    132.00    33
# 18   18.0    132.00    34
# 19    4.0    132.00    33
# 20  192.0    132.00    60
# 21    6.0    132.00    33
# 22  139.0    132.00    62
# 23  180.0    132.00    48
# 24  151.0    148.00    58
# 25    7.0    148.00    33
# 26   18.0    148.00    34
# 27    4.0    148.00    33
# 28  102.0    148.00    60
# 29    6.0    148.00    33
# 30  135.0    148.00    62
# 31  162.0    148.00    48
# 32   18.0    151.50    34
# 33    7.0    151.50    33
# 34  167.0    151.50    58
# 35   66.0    151.50    60
# 36    4.0    151.50    33
# 37   97.0    151.50    62
# 38    6.0    151.50    33
# 39  150.0    151.50    48
# 40    7.0    151.20    33
# 41  193.0    151.20    58
# 42   18.0    151.20    34
# 43    4.0    151.20    33
# 44  148.0    151.20    60
# 45    6.0    151.20    33
# 46   99.0    151.20    62
# 47   62.0    151.20    48
# 48   43.0    136.33    58
# 49    7.0    136.33    33
#     Value  Feature2  Code
# 0    23.0       NaN    34
# 1     6.0       NaN    33
# 2   234.0       NaN    58
# 3   212.0       NaN    60
# 4     4.0       NaN    33
# 5   226.0       NaN    62
# 6     6.0       NaN    33
# 7   207.0       NaN    48
# 8   212.0    207.00    58
# 9    23.0    207.00    34
# 10    6.0    207.00    33
# 11    4.0    207.00    33
# 12  171.0    207.00    60
# 13    6.0    207.00    33
# 14  193.0    207.00    62
# 15  187.0    207.00    48
# 16   23.0    197.00    34
# 17    6.0    197.00    33
# 18  233.0    197.00    58
# 19    4.0    197.00    33
# 20  198.0    197.00    60
# 21  194.0    197.00    62
# 22    6.0    197.00    33
# 23  176.0    197.00    48
# 24  261.0    190.00    58
# 25   23.0    190.00    34
# 26    6.0    190.00    33
# 27  199.0    190.00    60
# 28    4.0    190.00    33
# 29  187.0    190.00    62
# 30    6.0    190.00    33
# 31  209.0    190.00    48
# 32   23.0    194.75    34
# 33    6.0    194.75    33
# 34  227.0    194.75    58
# 35    4.0    194.75    33
# 36  191.0    194.75    60
# 37    6.0    194.75    33
# 38  159.0    194.75    62
# 39  183.0    194.75    48
# 40   23.0    192.40    34
# 41    6.0    192.40    33
# 42  298.0    192.40    58
# 43    4.0    192.40    33
# 44  235.0    192.40    60
# 45    6.0    192.40    33
# 46  186.0    192.40    62
# 47  199.0    192.40    48
# 48    6.0    193.50    33
# 49  292.0    193.50    58
#     Value  Feature2  Code
# 0     5.0       NaN    33
# 1    27.0       NaN    34
# 2   101.0       NaN    58
# 3    89.0       NaN    60
# 4     3.0       NaN    33
# 5     6.0       NaN    33
# 6    94.0       NaN    62
# 7   109.0       NaN    48
# 8    27.0    109.00    34
# 9     5.0    109.00    33
# 10  174.0    109.00    58
# 11    3.0    109.00    33
# 12  148.0    109.00    60
# 13    6.0    109.00    33
# 14  143.0    109.00    62
# 15  137.0    109.00    48
# 16   27.0    123.00    34
# 17    5.0    123.00    33
# 18  155.0    123.00    58
# 19    3.0    123.00    33
# 20  144.0    123.00    60
# 21  101.0    123.00    62
# 22   99.0    123.00    48
# 23    5.0    115.00    33
# 24   71.0    115.00    58
# 25   27.0    115.00    34
# 26    3.0    115.00    33
# 27   62.0    115.00    60
# 28    6.0    115.00    33
# 29   78.0    115.00    62
# 30   88.0    115.00    48
# 31  109.0    108.25    58
# 32    5.0    108.25    33
# 33   27.0    108.25    34
# 34    3.0    108.25    33
# 35  137.0    108.25    60
# 36    6.0    108.25    33
# 37  125.0    108.25    62
# 38  187.0    108.25    48
# 39    5.0    124.00    33
# 40  215.0    124.00    58
# 41   27.0    124.00    34
# 42    3.0    124.00    33
# 43  167.0    124.00    60
# 44  180.0    124.00    62
# 45    6.0    124.00    33
# 46  161.0    124.00    48
# 47    5.0    130.17    33
# 48   27.0    130.17    34
# 49  156.0    130.17    58
#     Value  Feature2  Code
# 0   175.0       NaN    57
# 1   110.0    175.00    60
# 2     5.0    175.00    33
# 3   361.0    175.00    62
# 4    10.0    175.00    33
# 5     1.0    175.00    34
# 6    13.0    175.00    33
# 7     0.0    175.00    71
# 8     0.0    175.00    66
# 9   300.0    175.00    57
# 10    0.0    237.50    71
# 11  165.0    237.50    57
# 12    0.0    213.33    66
# 13    6.0    213.33    33
# 14  194.0    213.33    60
# 15    6.0    213.33    33
# 16    0.0    213.33    67
# 17   83.0    213.33    62
# 18  177.0    213.33    64
# 19    2.0    213.33    33
# 20    6.0    213.33    34
# 21    0.0    213.33    71
# 22  228.0    213.33    57
# 23  224.0    217.00    60
# 24    6.0    217.00    33
# 25   62.0    217.00    62
# 26    7.0    217.00    33
# 27  111.0    217.00    64
# 28    2.0    217.00    33
# 29    6.0    217.00    34
# 30  255.0    217.00    58
# 31    0.0    217.00    67
# 32    8.0    217.00    33
# 33  254.0    217.00    60
# 34  299.0    217.00    62
# 35    0.0    217.00    67
# 36    0.0    217.00    71
# 37   10.0    217.00    33
# 38    1.0    217.00    34
# 39   71.0    217.00    64
# 40    2.0    217.00    33
# 41    6.0    217.00    34
# 42   88.0    217.00    58
# 43    6.0    217.00    33
# 44  211.0    217.00    60
# 45    6.0    217.00    33
# 46    0.0    217.00    67
# 47  116.0    217.00    62
# 48  221.0    217.00    64
# 49    0.0    217.00    67
#     Value  Feature2  Code
# 0     1.0       NaN    34
# 1   320.0       NaN    63
# 2     3.0       NaN    33
# 3     7.0       NaN    34
# 4     0.0       NaN    71
# 5    80.0       NaN    58
# 6     6.0       NaN    33
# 7    72.0       NaN    60
# 8     5.0       NaN    33
# 9     0.0       NaN    70
# 10   92.0       NaN    62
# 11    0.0       NaN    72
# 12    6.0       NaN    33
# 13   86.0       NaN    64
# 14    0.0       NaN    70
# 15    2.0       NaN    33
# 16    5.0       NaN    34
# 17  284.0       NaN    58
# 18    0.0       NaN    67
# 19    8.0       NaN    33
# 20   84.0       NaN    60
# 21    5.0       NaN    33
# 22  230.0       NaN    62
# 23    0.0       NaN    71
# 24    1.0       NaN    34
# 25    8.0       NaN    33
# 26   54.0       NaN    64
# 27    0.0       NaN    68
# 28    0.0       NaN    72
# 29    2.0       NaN    33
# 30    5.0       NaN    34
# 31  222.0       NaN    58
# 32    8.0       NaN    33
# 33    0.0       NaN    67
# 34   84.0       NaN    60
# 35    0.0       NaN    70
# 36    5.0       NaN    33
# 37   86.0       NaN    62
# 38    0.0       NaN    70
# 39    6.0       NaN    33
# 40   71.0       NaN    57
# 41    0.0      71.0    70
# 42    6.0      71.0    34
# 43    2.0      71.0    33
# 44  178.0      71.0    58
# 45  210.0      71.0    60
# 46    0.0      71.0    71
# 47    5.0      71.0    33
# 48  254.0      71.0    62
# 49    0.0      71.0    71
#     Value  Feature2  Code
# 0   219.0       NaN    59
# 1     7.0       NaN    33
# 2   119.0       NaN    60
# 3     5.0       NaN    33
# 4    74.0       NaN    62
# 5     0.0       NaN    70
# 6     6.0       NaN    33
# 7     0.0       NaN    65
# 8   146.0       NaN    64
# 9    86.0       NaN    58
# 10    6.0       NaN    33
# 11  183.0       NaN    60
# 12    0.0       NaN    71
# 13    5.0       NaN    33
# 14  171.0       NaN    62
# 15    8.0       NaN    33
# 16  130.0       NaN    64
# 17    2.0       NaN    33
# 18    6.0       NaN    34
# 19   67.0       NaN    58
# 20    5.0       NaN    33
# 21  103.0       NaN    60
# 22    5.0       NaN    33
# 23  111.0       NaN    62
# 24    7.0       NaN    33
# 25   82.0       NaN    64
# 26    2.0       NaN    33
# 27    5.0       NaN    34
# 28    0.0       NaN    69
# 29  105.0       NaN    58
# 30    6.0       NaN    33
# 31  103.0       NaN    60
# 32  174.0       NaN    62
# 33    8.0       NaN    33
# 34  197.0       NaN    64
# 35    7.0       NaN    34
# 36    2.0       NaN    33
# 37  196.0       NaN    58
# 38  238.0       NaN    60
# 39    0.0       NaN    71
# 40  281.0       NaN    62
# 41    0.0       NaN    71
# 42    8.0       NaN    33
# 43  214.0       NaN    64
# 44  160.0       NaN    58
# 45  184.0       NaN    60
# 46    6.0       NaN    33
# 47   77.0       NaN    62
# 48    6.0       NaN    33
# 49  135.0       NaN    64
#     Value  Feature2  Code
# 0    62.0       NaN    62
# 1     0.0       NaN    65
# 2     6.0       NaN    33
# 3   257.0       NaN    64
# 4     3.0       NaN    33
# 5     7.0       NaN    34
# 6   195.0       NaN    58
# 7     7.0       NaN    33
# 8     2.0       NaN    34
# 9    84.0       NaN    60
# 10    5.0       NaN    33
# 11  179.0       NaN    62
# 12    8.0       NaN    33
# 13  198.0       NaN    64
# 14    2.0       NaN    33
# 15    7.0       NaN    34
# 16  165.0       NaN    58
# 17    6.0       NaN    33
# 18    2.0       NaN    34
# 19  108.0       NaN    60
# 20    5.0       NaN    33
# 21  204.0       NaN    62
# 22    8.0       NaN    33
# 23  221.0       NaN    64
# 24    0.0       NaN    71
# 25    7.0       NaN    34
# 26    2.0       NaN    33
# 27  114.0       NaN    58
# 28  152.0       NaN    60
# 29    5.0       NaN    33
# 30  113.0       NaN    62
# 31    7.0       NaN    33
# 32   74.0       NaN    64
# 33    2.0       NaN    33
# 34    5.0       NaN    34
# 35   69.0       NaN    58
# 36    6.0       NaN    33
# 37   58.0       NaN    60
# 38    5.0       NaN    33
# 39   75.0       NaN    62
# 40    6.0       NaN    33
# 41  302.0       NaN    64
# 42    0.0       NaN    67
# 43    7.0       NaN    34
# 44    3.0       NaN    33
# 45  183.0       NaN    58
# 46    2.0       NaN    34
# 47    7.0       NaN    33
# 48   94.0       NaN    60
# 49    5.0       NaN    33
#     Value  Feature2  Code
# 0     0.0       NaN    65
# 1     0.0       NaN    67
# 2    39.0       NaN    57
# 3     0.0      39.0    65
# 4   282.0      39.0    58
# 5   216.0      39.0    60
# 6   207.0      39.0    57
# 7   180.0     123.0    64
# 8   152.0     123.0    58
# 9   216.0     123.0    60
# 10  197.0     123.0    62
# 11  217.0     123.0    64
# 12  189.0     123.0    58
# 13  223.0     123.0    60
# 14  107.0     123.0    62
# 15   68.0     123.0    64
# 16    0.0     123.0    68
# 17  272.0     123.0    58
# 18    0.0     123.0    67
# 19   71.0     123.0    60
# 20  298.0     123.0    62
# 21  235.0     123.0    64
# 22    0.0     123.0    71
# 23  131.0     123.0    58
# 24  138.0     123.0    60
# 25   65.0     123.0    62
# 40   26.0    180.36    35
# 41    0.0    180.36    66
# 42  180.0    180.36    57
# 43   10.0    180.33    33
# 44    0.0    180.33    66
# 45  242.0    180.33    57
# 46   10.0    184.19    33
# 47    0.0    184.19    66
# 48  224.0    184.19    57
# 49  274.0    186.53    57
#     Value  Feature2  Code
# 0    40.0       NaN    34
# 1   235.0       NaN    58
# 2    18.0       NaN    33
# 3   195.0       NaN    60
# 4    10.0       NaN    33
# 5   158.0       NaN    62
# 6    14.0       NaN    33
# 7   219.0       NaN    48
# 8   219.0    219.00    58
# 9    18.0    219.00    33
# 10   40.0    219.00    34
# 11   13.0    219.00    33
# 12  211.0    219.00    60
# 13   17.0    219.00    33
# 14  215.0    219.00    62
# 15  341.0    219.00    48
# 16   15.0    280.00    33
# 17   40.0    280.00    34
# 18  149.0    280.00    58
# 19  280.0    280.00    60
# 20   14.0    280.00    33
# 21   16.0    280.00    33
# 22  310.0    280.00    48
# 23   40.0    290.00    34
# 24  154.0    290.00    58
# 25   15.0    290.00    33
# 26  145.0    290.00    60
# 27   10.0    290.00    33
# 28  100.0    290.00    62
# 29   14.0    290.00    33
# 30  236.0    290.00    48
# 31   40.0    276.50    34
# 32   19.0    276.50    33
# 33  259.0    276.50    58
# 34   14.0    276.50    33
# 35   63.0    276.50    62
# 36  261.0    276.50    48
# 37   40.0    273.40    34
# 38   18.0    273.40    33
# 39  203.0    273.40    58
# 40   10.0    273.40    33
# 41   51.0    273.40    60
# 42   18.0    273.40    33
# 43  277.0    273.40    62
# 44  276.0    273.40    48
# 45   15.0    273.83    33
# 46  178.0    273.83    58
# 47   40.0    273.83    34
# 48  197.0    273.83    60
# 49   10.0    273.83    33
#     Value  Feature2  Code
# 0   134.0       NaN    58
# 1    20.0       NaN    34
# 2   158.0       NaN    60
# 3   258.0       NaN    62
# 4   115.0       NaN    58
# 5    20.0       NaN    34
# 6   162.0       NaN    60
# 7   135.0       NaN    62
# 8    20.0       NaN    34
# 9   100.0       NaN    58
# 10  148.0       NaN    60
# 11  147.0       NaN    62
# 12  129.0       NaN    58
# 13   20.0       NaN    34
# 14  136.0       NaN    60
# 15  160.0       NaN    62
# 16  118.0       NaN    58
# 17   20.0       NaN    34
# 18  105.0       NaN    62
# 19   20.0       NaN    34
# 20  148.0       NaN    58
# 21  132.0       NaN    60
# 22  140.0       NaN    62
# 23   13.0       NaN    34
# 24   91.0       NaN    58
# 25  130.0       NaN    60
# 26  147.0       NaN    62
# 27   20.0       NaN    34
# 28  135.0       NaN    58
# 29  144.0       NaN    60
# 30  137.0       NaN    62
# 31  124.0       NaN    58
# 32   20.0       NaN    34
# 33  130.0       NaN    60
# 34  116.0       NaN    62
# 35   20.0       NaN    34
# 36   98.0       NaN    58
# 37  138.0       NaN    60
# 38  114.0       NaN    62
# 39   84.0       NaN    58
# 40   20.0       NaN    34
# 41   76.0       NaN    60
# 42  157.0       NaN    62
# 43  118.0       NaN    58
# 44   20.0       NaN    34
# 45  124.0       NaN    60
# 46  148.0       NaN    62
# 47  112.0       NaN    58
# 48   20.0       NaN    34
# 49  134.0       NaN    60
#     Value  Feature2  Code
# 0   323.0       NaN    57
# 1   319.0    323.00    57
# 2   138.0    321.00    57
# 3   110.0    260.00    57
# 4   112.0    222.50    57
# 5   281.0    200.40    57
# 6    59.0    213.83    57
# 7   251.0    191.71    57
# 8   359.0    199.12    57
# 9   342.0    216.89    57
# 10  344.0    229.40    57
# 11  266.0    239.82    57
# 12  242.0    242.00    63
# 13  164.0    242.00    57
# 14  161.0    236.00    57
# 15  151.0    230.64    57
# 16  130.0    225.33    57
# 17  326.0    219.38    57
# 18  126.0    225.65    57
# 19  190.0    220.11    57
# 20  265.0    218.53    57
# 21  220.0    220.85    57
# 22  117.0    220.81    57
# 23  146.0    216.09    57
# 24  178.0    213.04    57
# 25  174.0    211.58    57
# 26   83.0    210.08    57
# 27  291.0    205.19    57
# 28  194.0    208.37    57
# 29  194.0    207.86    57
# 30  130.0    207.38    57
# 31  113.0    204.80    57
# 32  106.0    201.84    57
# 33   85.0    198.84    57
# 34  162.0    195.39    57
# 35  213.0    194.41    57
# 36  230.0    194.94    57
# 37  257.0    195.92    57
# 38  385.0    197.57    57
# 39  198.0    202.50    57
# 40   67.0    202.38    57
# 41  303.0    199.00    57
# 42  358.0    201.54    57
# 43   54.0    205.26    57
# 44  501.0    201.74    57
# 45  133.0    208.55    57
# 46  144.0    206.87    57
# 47  120.0    205.50    57
# 48  265.0    203.68    57
#     Value  Feature2  Code
# 0     2.0       NaN    33
# 1     8.0       NaN    34
# 2   354.0       NaN    58
# 3     7.0       NaN    34
# 4   275.0       NaN    62
# 5     1.0       NaN    33
# 6     8.0       NaN    34
# 7    66.0       NaN    58
# 8     0.0       NaN    33
# 9   104.0       NaN    62
# 10    1.0       NaN    33
# 11    7.0       NaN    34
# 12    8.0       NaN    34
# 13    1.0       NaN    33
# 14  233.0       NaN    58
# 15    1.0       NaN    33
# 16    7.0       NaN    34
# 17  310.0       NaN    48
# 18  221.0    310.00    58
# 19    8.0    310.00    34
# 20    1.0    310.00    33
# 21  243.0    310.00    62
# 22    1.0    310.00    33
# 23    7.0    310.00    34
# 24    8.0    310.00    34
# 25  155.0    310.00    58
# 26    1.0    310.00    33
# 27    1.0    310.00    33
# 28    7.0    310.00    34
# 29  400.0    310.00    48
# 30    1.0    355.00    33
# 31    8.0    355.00    34
# 32  344.0    355.00    33
# 33  250.0    355.00    62
# 34    7.0    355.00    34
# 35    1.0    355.00    33
# 36    1.0    355.00    33
# 37    8.0    355.00    34
# 38  375.0    355.00    60
# 39    1.0    355.00    33
# 40    7.0    355.00    34
# 41   71.0    355.00    48
# 42    1.0    260.33    33
# 43    8.0    260.33    34
# 44  133.0    260.33    58
# 45    7.0    260.33    34
# 46    1.0    260.33    33
# 47   40.0    260.33    48
# 48    1.0    205.25    33
# 49  245.0    205.25    58

# %%
#Average of all Blood sugar levels in the same category - pre
for i in range(1,71):
    average=0
    sum=0
    count=1

    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        if(code== 58) | (code == 60)|(code== 62) | (code == 64):
            sum=sum+value
            average=sum/count
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    seri=pd.Series(liste)
    datapatient["Feature3_Pre"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
##Average of all Blood sugar levels in the same category - post

for i in range(1,71):
    average=0
    sum=0
    count=1
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        if(code== 59) | (code == 61)|(code== 63):
            sum=sum+value
            average=sum/count
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    seri=pd.Series(liste)
    datapatient["Feature3_Post"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all Blood sugar levels up to that date within the same time zone.

#Here, to be able to apply to_datetime function, there was unclear entries in Time column
#All of them (38 items) have been deleted. These are the ones that I assigned big values while finding TimeStamp columns.
#I just deleted the items from Value-Replaced file.
from datetime import datetime

tz1="00:00:00"
tz2="06:00:00"
tz3="12:00:00"
tz4="18:00:00"
tz5="23:59:59"

converted_tz1=datetime.strptime(tz1, '%H:%M:%S').time()
converted_tz2=datetime.strptime(tz2, '%H:%M:%S').time()
converted_tz3=datetime.strptime(tz3, '%H:%M:%S').time()
converted_tz4=datetime.strptime(tz4, '%H:%M:%S').time()
converted_tz5=datetime.strptime(tz5, '%H:%M:%S').time()

# %%
#Average of all Blood sugar levels up to that date within the same time zone. BedTime, Moning, Evening, Night
for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M").dt.time
    avrgb = 0
    avrgM = 0
    avrgE = 0
    avrgN = 0
    
    sumb = 0
    sumM=0
    sumN=0
    sumE=0
    countb = 1
    countM=1
    countE=1
    countN=1
    
    countere=1
    counterb=1
    counterm=1
    countern=1
    liste.insert(0,np.nan)
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        if ((code == 48) | (code == 57) | (code == 58) | (code == 59) | (code == 60) | (code == 61) | (code == 62) | (code == 63) | (code == 64)):  # filtering according to codes
            
            if ((time>=converted_tz1) & (time<=converted_tz2)): #bedtime
                if counterb==1:
                    liste.append(liste[len(liste) - 1])
                    sumb=sumb+value
                    avrgb=sumb
                    counterb=counterb+1
                    countb=countb+1
                else:
                    liste.append(avrgb)
                    sumb=sumb+value
                    avrgb = sumb / countb
                    countb += 1
            elif ((time>=converted_tz2) & (time<=converted_tz3)): #morning
                
                if counterm==1:
                    liste.append(liste[len(liste) - 1])
                    sumM = value
                    avrgM = sumM
                    counterm=counterm+1
                    countM +=1
                
                else:
                    liste.append(avrgM)
                    sumM=sumM + value
                    avrgM =sumM /countM
                    countM +=1
                
            elif ((time>=converted_tz3) & (time<=converted_tz4)): #Evening
                
                if countere==1:
                        liste.append(liste[len(liste) - 1])
                        sumE = value
                        avrgE = sumE
                        countere +=1
                        countE +=1
                else:
                        liste.append(avrgE)
                        sumE = sumE + value
                        avrgE = sumE /countE
                        countE +=1
                
            elif ((time>=converted_tz4) & (time<=converted_tz5)): #Night
                if countern==1:
                    liste.append(liste[len(liste) - 1])
                    sumN = value
                    avrgN = sumN
                    countern += 1
                    countN +=1
                else:
                    liste.append(avrgN)
                    sumN = sumN + value
                    avrgN = sumN / countN 
                    countN +=1
        else:
            liste.append(liste[len(liste) - 1])
   # print(liste)
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature4_BMEN"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all Blood sugar levels up to that date within the same time zone.Work Non Work
for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    avrgNon = 0
    avrgW = 0
    sumNon=0
    sumW=0
    countNon=1
    counterNon=1
    counterW = 1
    countW=1
    liste.insert(0,np.nan)
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        if ((code == 48) | (code == 57) | (code == 58) | (code == 59) | (
                code == 60) | (code == 61) | (code == 62) | (
                code == 63) | (code == 64)):  # filtering according to codes
            
            if ((time>=converted_tz2) & (time<=converted_tz4)): #workhr
                
                if counterW==1: # To make up to date
                    liste.append(liste[len(liste) - 1])
                    sumW = value
                    avrgW= sumW
                    counterW += 1
                    countW +=1
                else:
                    liste.append(avrgW)
                    sumW = sumW + value
                    avrgW = round( sumW / countW,2)
                    countW += 1
            elif ((time>=converted_tz1)  & (time<=converted_tz2)) | ((time >= converted_tz4) & (time<= converted_tz5)):
            
                if counterNon==1:
                    liste.append(liste[len(liste) - 1])
                    sumNon = value
                    avrgNon = sumNon
                    countNon += 1
                    counterNon += 1
                else:
                    liste.append(avrgNon)
                    sumNon = sumNon + value
                    avrgNon = round(sumNon / countNon,2)
                    countNon += 1
        else:
            liste.append(liste[len(liste) - 1])
   # print(liste)
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature4_Work_NonWork"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all Blood sugar levels in the same category up to that date within the same time zone. PRE Bed morning evening night

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    
    avrgb = 0
    avrgM = 0
    avrgE = 0
    avrgN = 0
    sumb = 0
    sumM=0
    sumN=0
    sumE=0
    countb = 1
    countM=1
    countE=1
    countN=1
    
    countere=1
    counterb=1
    counterm=1
    countern=1
    liste.insert(0,np.nan)
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        
        if ((code == 58) | (code == 60) | (code == 62) | (code == 64)):  # filtering according to codes
            
            if ((time>=converted_tz1) & (time<=converted_tz2)): #bedtime
                if counterb==1:
                    liste.append(liste[len(liste) - 1])
                    sumb = value
                    avrgb = sumb
                    counterb += 1
                    countb += 1
                else:
                    liste.append(avrgb)
                    sumb = sumb + value
                    avrgb = sumb / countb
                    countb += 1
                    
            elif ((time>=converted_tz2) & (time<=converted_tz3)):#mor ning   
                
                if counterm==1:
                    liste.append(liste[len(liste) - 1])
                    sumM = value
                    avrgM = sumM
                    counterm=counterm+1
                    countM +=1
                else:
                    liste.append(avrgM)
                    sumM=sumM + value
                    avrgM =sumM /countM
                    countM +=1
            
            elif ((time>=converted_tz3) & (time<=converted_tz4)):#evening
                if countere==1:
                    liste.append(liste[len(liste) - 1])
                    sumE = value
                    avrgE = sumE
                    countere +=1
                    countE +=1
                else:
                    liste.append(avrgE)
                    sumE = sumE + value
                    avrgE = sumE /countE
                    countE +=1
            elif  ((time>=converted_tz4) & (time<=converted_tz5)): # night
                if countern==1:
                    liste.append(liste[len(liste) - 1])
                    sumN = value
                    avrgN = sumN
                    countern += 1
                    countN +=1
                else:
                    liste.append(avrgN)
                    sumN = sumN + value
                    avrgN = sumN / countN 
                    countN +=1
                    
        else:
            liste.append(liste[len(liste) - 1])
   # print(liste)
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature5Pre_BMEN"]=seri
    a=datapatient[datapatient["Code"].isin([48,58,60,62,64])]
    print(a[["Feature5Pre_BMEN","Value","Code","Time"]].head(50))

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )
# Out:
#      Feature5Pre_BMEN  Value  Code      Time
# 2                 NaN  100.0    58  09:09:00
# 3                 NaN  119.0    62  17:08:00
# 5                 NaN  123.0    48  22:51:00
# 8          100.000000  216.0    58  07:35:00
# 10         119.000000  211.0    62  16:56:00
# 13         158.000000  257.0    58  07:25:00
# 15         165.000000  129.0    62  17:25:00
# 18         191.000000  239.0    58  07:52:00
# 21         153.000000  129.0    62  17:10:00
# 22         153.000000  340.0    48  22:09:00
# 25         203.000000   67.0    58  07:29:00
# 29         147.000000  206.0    62  17:24:00
# 30         147.000000  288.0    48  21:54:00
# 32         147.000000   77.0    58  05:52:00
# 37         158.800000  228.0    62  17:26:00
# 40         175.800000  259.0    58  10:03:00
# 42         170.333333  256.0    62  17:20:00
# 44         189.666667  109.0    58  08:42:00
# 46         182.571429   96.0    62  17:06:00
# 3         134.000000  258.0    62  18:00:00
# 4         146.000000  115.0    58  08:00:00
# 6         135.666667  162.0    60  12:00:00
# 7         258.000000  135.0    62  18:00:00
# 9         142.250000  100.0    58  08:00:00
# 10        133.800000  148.0    60  12:00:00
# 11        196.500000  147.0    62  18:00:00
# 12        136.166667  129.0    58  08:00:00
# 14        135.142857  136.0    60  12:00:00
# 15        180.000000  160.0    62  18:00:00
# 16        135.250000  118.0    58  08:00:00
# 18        175.000000  105.0    62  18:00:00
# 20        133.333333  148.0    58  08:00:00
# 21        134.800000  132.0    60  12:00:00
# 22        161.000000  140.0    62  18:00:00
# 24        134.545455   91.0    58  08:00:00
# 25        130.916667  130.0    60  12:00:00
# 26        157.500000  147.0    62  18:00:00
# 28        130.846154  135.0    58  08:00:00
# 29        131.142857  144.0    60  12:00:00
# 30        156.000000  137.0    62  18:00:00
# 31        132.000000  124.0    58  08:00:00
# 33        131.500000  130.0    60  12:00:00
# 34        153.625000  116.0    62  18:00:00
# 36        131.411765   98.0    58  08:00:00
# 37        129.555556  138.0    60  12:00:00
# 38        149.444444  114.0    62  18:00:00
# 39        130.000000   84.0    58  08:00:00
# 41        127.700000   76.0    60  12:00:00
# 42        145.900000  157.0    62  18:00:00
# 43        125.238095  118.0    58  08:00:00
# 45        124.909091  124.0    60  12:00:00
# 46        146.909091  148.0    62  18:00:00
# 47        124.869565  112.0    58  08:00:00
# 49        124.333333  134.0    60  12:00:00
# 50        147.000000  142.0    62  18:00:00
# 51        124.720000  117.0    58  08:00:00
# 53        124.423077  128.0    60  12:00:00
# 54        146.615385  119.0    62  18:00:00
# 56        124.555556   94.0    58  08:00:00
# 57        123.464286  110.0    60  12:00:00
# 58        144.642857  147.0    62  18:00:00
# 60        123.000000  120.0    58  08:00:00
# 61        122.900000  106.0    60  12:00:00
# 62        144.800000  138.0    62  18:00:00
# 63        122.354839  115.0    58  08:00:00
# 65        122.125000   77.0    60  12:00:00
# 66        144.375000  111.0    62  18:00:00
# Empty DataFrame
# Columns: [Feature5Pre_BMEN, Value, Code, Time]
# Index: []
#      Feature5Pre_BMEN  Value  Code      Time
# 2                 NaN  354.0    58  08:00:00
# 4                 NaN  275.0    62  18:00:00
# 7          354.000000   66.0    58  08:00:00
# 9          275.000000  104.0    62  18:00:00
# 14         210.000000  233.0    58  08:00:00
# 17         210.000000  310.0    48  22:00:00
# 18         217.666667  221.0    58  08:00:00
# 21         189.500000  243.0    62  18:00:00
# 25         218.500000  155.0    58  08:00:00
# 29         218.500000  400.0    48  22:00:00
# 33         207.333333  250.0    62  18:00:00
# 38         205.800000  375.0    60  12:00:00
# 41         205.800000   71.0    48  22:00:00
# 44         234.000000  133.0    58  08:00:00
# 47         234.000000   40.0    48  22:00:00
# 49         219.571429  245.0    58  08:00:00
# 51         218.000000  311.0    62  18:00:00
# 54         222.750000  102.0    58  08:00:00
# 59         222.750000   73.0    48  22:00:00
# 60         209.333333  221.0    58  08:00:00
# 65         236.600000   85.0    62  18:00:00
# 66         210.500000  144.0    58  08:00:00
# 69         211.333333   86.0    62  18:00:00
# 74         204.454545  322.0    60  12:00:00
# 77         204.454545  195.0    48  22:00:00
# 80         214.250000   99.0    60  12:00:00
# 83         214.250000  253.0    48  22:00:00
# 86         205.384615  120.0    58  08:00:00
# 88         193.428571   80.0    62  18:00:00
# 93         179.250000  400.0    62  18:00:00
# 95         179.250000   64.0    48  22:00:00
# 98         199.285714  107.0    58  08:00:00
# 100        203.777778  400.0    62  18:00:00
# 104        223.400000  317.0    62  18:00:00
# 107        223.400000   68.0    48  22:00:00
# 110        231.909091  400.0    62  18:00:00
# 115        245.916667  361.0    62  18:00:00
# 118        245.916667  127.0    48  22:00:00
# 121        193.133333  304.0    60  12:00:00
# 124        254.769231  338.0    62  18:00:00
# 127        200.062500  194.0    58  08:00:00
# 130        260.714286  400.0    62  18:00:00
# 131        199.705882   51.0    58  08:00:00
# 134        270.000000  400.0    62  18:00:00
# 138        191.444444  199.0    58  08:00:00
# 141        191.444444   61.0    48  22:00:00
# 144        191.842105  180.0    58  08:00:00
# 147        191.842105  128.0    48  22:00:00
# 150        191.250000  183.0    58  08:00:00
# 153        278.125000  166.0    62  18:00:00

# %%
#Average of all Blood sugar levels in the same category up to that date within the same time zone. Pre Work-NonWork
for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    
    avrgb = 0
    avrgM = 0

    sumb = 0
    sumM=0
    
    countb = 1
    countM=1
    
    counterb=1
    counterm=1

    liste.insert(0,np.nan)
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        
        if ((code == 58) | (code == 60) | (code == 62) | (code == 64)):  # filtering according to codes
            
            if ((time>=converted_tz2) & (time<=converted_tz4)): #work
                if counterb==1:
                    liste.append(liste[len(liste) - 1])
                    sumb = value
                    avrgb = sumb
                    counterb += 1
                    countb += 1
                else:
                    liste.append(avrgb)
                    sumb = sumb + value
                    avrgb = sumb / countb
                    countb += 1
                    
            elif ((time>=converted_tz1)  & (time<=converted_tz2)) | ((time >= converted_tz4) & (time<= converted_tz5)):#nonwork
                if counterm==1:
                    liste.append(liste[len(liste) - 1])
                    sumM = value
                    avrgM = sumM
                    counterm=counterm+1
                    countM +=1
                else:
                    liste.append(avrgM)
                    sumM=sumM + value
                    avrgM =sumM /countM
                    countM +=1
            
                    
        else:
            liste.append(liste[len(liste) - 1])
   # print(liste)
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature5Pre_WorkNonWork"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all Blood sugar levels in the same category up to that date within the same time zone. Post Morning Evening Bed Night
for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    
    avrgb = 0
    avrgM = 0
    avrgE = 0
    avrgN = 0
    sumb = 0
    sumM=0
    sumN=0
    sumE=0
    countb = 1
    countM=1
    countE=1
    countN=1
    
    countere=1
    counterb=1
    counterm=1
    countern=1
    liste.insert(0,np.nan)
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        
        if ((code == 59) | (code == 61) | (code == 63)):  # filtering according to codes
            
            if ((time>=converted_tz1) & (time<=converted_tz2)): #bedtime
                if counterb==1:
                    liste.append(liste[len(liste) - 1])
                    sumb = value
                    avrgb = sumb
                    counterb += 1
                    countb += 1
                else:
                    liste.append(avrgb)
                    sumb = sumb + value
                    avrgb = sumb / countb
                    countb += 1
                    
            elif ((time>=converted_tz2) & (time<=converted_tz3)):#mor ning   
                
                if counterm==1:
                    liste.append(liste[len(liste) - 1])
                    sumM = value
                    avrgM = sumM
                    counterm=counterm+1
                    countM +=1
                else:
                    liste.append(avrgM)
                    sumM=sumM + value
                    avrgM =sumM /countM
                    countM +=1
            
            elif ((time>=converted_tz3) & (time<=converted_tz4)):#evening
                if countere==1:
                    liste.append(liste[len(liste) - 1])
                    sumE = value
                    avrgE = sumE
                    countere +=1
                    countE +=1
                else:
                    liste.append(avrgE)
                    sumE = sumE + value
                    avrgE = sumE /countE
                    countE +=1
            elif  ((time>=converted_tz4) & (time<=converted_tz5)): # night
                if countern==1:
                    liste.append(liste[len(liste) - 1])
                    sumN = value
                    avrgN = sumN
                    countern += 1
                    countN +=1
                else:
                    liste.append(avrgN)
                    sumN = sumN + value
                    avrgN = sumN / countN 
                    countN +=1
                    
        else:
            liste.append(liste[len(liste) - 1])
   # print(liste)
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature5Post_BMEN"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all Blood sugar levels in the same category up to that date within the same time zone. Post Work NonWork
for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    
    avrgb = 0
    avrgM = 0

    sumb = 0
    sumM=0
    
    countb = 1
    countM=1
    
    counterb=1
    counterm=1

    liste.insert(0,np.nan)
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        
        if ((code == 59) | (code == 61) | (code == 63)):  # filtering according to codes
            
            if ((time>=converted_tz2) & (time<=converted_tz4)): #work
                if counterb==1:
                    liste.append(liste[len(liste) - 1])
                    sumb = value
                    avrgb = sumb
                    counterb += 1
                    countb += 1
                else:
                    liste.append(avrgb)
                    sumb = sumb + value
                    avrgb = sumb / countb
                    countb += 1
                    
            elif ((time>=converted_tz1)  & (time<=converted_tz2)) | ((time >= converted_tz4) & (time<= converted_tz5)):#nonwork
                if counterm==1:
                    liste.append(liste[len(liste) - 1])
                    sumM = value
                    avrgM = sumM
                    counterm=counterm+1
                    countM +=1
                else:
                    liste.append(avrgM)
                    sumM=sumM + value
                    avrgM =sumM /countM
                    countM +=1
            
                    
        else:
            liste.append(liste[len(liste) - 1])
   # print(liste)
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature5Post_WorkNonWork"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all Blood sugar levels in the same category up to that date within the same time zone. Unspecified Bed Morning Night Evening
for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    
    avrgb = 0
    avrgM = 0
    avrgE = 0
    avrgN = 0
    sumb = 0
    sumM=0
    sumN=0
    sumE=0
    countb = 1
    countM=1
    countE=1
    countN=1
    
    countere=1
    counterb=1
    counterm=1
    countern=1
    liste.insert(0,np.nan)
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        
        if ((code == 48) | (code == 57)):  # filtering according to codes
            
            if ((time>=converted_tz1) & (time<=converted_tz2)): #bedtime
                if counterb==1:
                    liste.append(liste[len(liste) - 1])
                    sumb = value
                    avrgb = sumb
                    counterb += 1
                    countb += 1
                else:
                    liste.append(avrgb)
                    sumb = sumb + value
                    avrgb = sumb / countb
                    countb += 1
                    
            elif ((time>=converted_tz2) & (time<=converted_tz3)):#mor ning   
                
                if counterm==1:
                    liste.append(liste[len(liste) - 1])
                    sumM = value
                    avrgM = sumM
                    counterm=counterm+1
                    countM +=1
                else:
                    liste.append(avrgM)
                    sumM=sumM + value
                    avrgM =sumM /countM
                    countM +=1
            
            elif ((time>=converted_tz3) & (time<=converted_tz4)):#evening
                if countere==1:
                    liste.append(liste[len(liste) - 1])
                    sumE = value
                    avrgE = sumE
                    countere +=1
                    countE +=1
                else:
                    liste.append(avrgE)
                    sumE = sumE + value
                    avrgE = sumE /countE
                    countE +=1
            elif  ((time>=converted_tz4) & (time<=converted_tz5)): # night
                if countern==1:
                    liste.append(liste[len(liste) - 1])
                    sumN = value
                    avrgN = sumN
                    countern += 1
                    countN +=1
                else:
                    liste.append(avrgN)
                    sumN = sumN + value
                    avrgN = sumN / countN 
                    countN +=1
                    
        else:
            liste.append(liste[len(liste) - 1])
   # print(liste)
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature5Unsp_BMEN"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all Blood sugar levels in the same category up to that date within the same time zone. Unsp Work Non Work

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    
    avrgb = 0
    avrgM = 0

    sumb = 0
    sumM=0
    
    countb = 1
    countM=1
    
    counterb=1
    counterm=1

    liste.insert(0,np.nan)
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        
        if ((code == 48) | (code == 57)):  # filtering according to codes
            
            if ((time>=converted_tz2) & (time<=converted_tz4)): #work
                if counterb==1:
                    liste.append(liste[len(liste) - 1])
                    sumb = value
                    avrgb = sumb
                    counterb += 1
                    countb += 1
                else:
                    liste.append(avrgb)
                    sumb = sumb + value
                    avrgb = sumb / countb
                    countb += 1
                    
            elif ((time>=converted_tz1)  & (time<=converted_tz2)) | ((time >= converted_tz4) & (time<= converted_tz5)):#nonwork
                if counterm==1:
                    liste.append(liste[len(liste) - 1])
                    sumM = value
                    avrgM = sumM
                    counterm=counterm+1
                    countM +=1
                else:
                    liste.append(avrgM)
                    sumM=sumM + value
                    avrgM =sumM /countM
                    countM +=1
            
                    
        else:
            liste.append(liste[len(liste) - 1])
   # print(liste)
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature5Unsp_WorkNonWork"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all pre-breakfast Blood sugar levels up to that date.

for i in range(1,71):
    average=0
    sum=0
    count=1
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        if(code== 58):
            sum=sum+value
            average=round(sum/count,2)
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    seri=pd.Series(liste)
    datapatient["Feature6"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all pre-lunch Blood sugar levels up to that date.

for i in range(1,71):
    average=0
    sum=0
    count=1
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        if(code== 60):
            sum=sum+value
            average=round(sum/count,2)
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    seri=pd.Series(liste)
    datapatient["Feature7"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all pre-supper Blood sugar levels up to that date.
for i in range(1,71):
    average=0
    sum=0
    count=1
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        if(code== 62):
            sum=sum+value
            average=round(sum/count,2)
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    seri=pd.Series(liste)
    datapatient["Feature8"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all pre-snack Blood sugar levels up to that date.


for i in range(1,71):
    average=0
    sum=0
    count=1
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        if(code== 64):
            sum=sum+value
            average=round(sum/count,2)
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    seri=pd.Series(liste)
    datapatient["Feature9"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all post-breakfast Blood sugar levels up to that date.

for i in range(1,71):
    average=0
    sum=0
    count=1
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        if(code== 59):
            sum=sum+value
            average=round(sum/count,2)
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    seri=pd.Series(liste)
    datapatient["Feature11"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all post-lunch Blood sugar levels up to that date.

for i in range(1,71):
    average=0
    sum=0
    count=1
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        if(code== 61):
            sum=sum+value
            average=round(sum/count,2)
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    seri=pd.Series(liste)
    datapatient["Feature12"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all post-supper Blood sugar levels up to that date.

for i in range(1,71):
    average=0
    sum=0
    count=1
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        if(code== 63):
            sum=sum+value
            average=round(sum/count,2)
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    seri=pd.Series(liste)
    datapatient["Feature13"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all 00-06 Blood sugar levels up to that date.

for i in range(1,71):
    sum=0
    count=1
    avrg=0
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        
        if  ((code == 48) | (code == 57) | (code == 58) | (code == 59) | (code == 60) | (code == 61) | (code == 62) | (
                code == 63) | (code == 64)) & ((time>=converted_tz1) & (time<=converted_tz2)):
            sum = sum + value
            avrg = round((sum / count),3)
            liste.append(avrg)
            count += 1 
        else:
            liste.append(liste[len(liste) - 1])
            

    seri=pd.Series(liste)
    datapatient["Feature15"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all 06-12 Blood sugar levels up to that date.

for i in range(1,71):
    sum=0
    count=1
    avrg=0
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        
        if  ((code == 48) | (code == 57) | (code == 58) | (code == 59) | (code == 60) | (code == 61) | (code == 62) | (
                code == 63) | (code == 64)) & ((time>=converted_tz2) & (time<=converted_tz3)):
            sum = sum + value
            avrg = round((sum / count),3)
            liste.append(avrg)
            count += 1 
        else:
            liste.append(liste[len(liste) - 1])
            

    seri=pd.Series(liste)
    datapatient["Feature16"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all 12-18 Blood sugar levels up to that date.

for i in range(1,71):
    sum=0
    count=1
    avrg=0
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        
        if  ((code == 48) | (code == 57) | (code == 58) | (code == 59) | (code == 60) | (code == 61) | (code == 62) | (
                code == 63) | (code == 64)) & ((time>=converted_tz3) & (time<=converted_tz4)):
            sum = sum + value
            avrg = round((sum / count),3)
            liste.append(avrg)
            count += 1 
        else:
            liste.append(liste[len(liste) - 1])
            
    seri=pd.Series(liste)
    datapatient["Feature17"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all 18-24 Blood sugar levels up to that date.

for i in range(1,71):
    sum=0
    count=1
    avrg=0
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        
        if  ((code == 48) | (code == 57) | (code == 58) | (code == 59) | (code == 60) | (code == 61) | (code == 62) | (
                code == 63) | (code == 64)) & ((time>=converted_tz4) & (time<=converted_tz5)):
            sum = sum + value
            avrg = round((sum / count),3)
            liste.append(avrg)
            count += 1 
        else:
            liste.append(liste[len(liste) - 1])
            
    seri=pd.Series(liste)
    datapatient["Feature18"]=seri
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all 00-06 Food Intake levels up to that date.
for i in range(1,71):
    average=0
    sum=0
    count=1

    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        if(((code== 66)|(code== 67)|(code== 68))&
        ((time>=converted_tz1) & (time<=converted_tz2))):
            sum=sum+value+1
            average=sum/count
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    #print(liste)  
    seri=pd.Series(liste)
    datapatient["Feature19"]=seri
    datapatient["Feature19"]=datapatient["Feature19"].fillna(0)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all 06-12 Food Intake levels up to that date.

for i in range(1,71):
    average=0
    sum=0
    count=1

    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        if(((code== 66)|(code== 67)|(code== 68))&
        ((time>=converted_tz2) & (time<=converted_tz3))):
            sum=sum+value+1
            average=sum/count
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    #print(liste)  
    seri=pd.Series(liste)
    datapatient["Feature20"]=seri
    datapatient["Feature20"]=datapatient["Feature20"].fillna(0)
    
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all 12-18 Food Intake levels up to that date.
for i in range(1,71):
    average=0
    sum=0
    count=1

    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        if(((code== 66)|(code== 67)|(code== 68))&
        ((time>=converted_tz3) & (time<=converted_tz4))):
            sum=sum+value+1
            average=sum/count
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    #print(liste)  
    seri=pd.Series(liste)
    datapatient["Feature21"]=seri
    datapatient["Feature21"]=datapatient["Feature21"].fillna(0)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all 18-24 Food Intake levels up to that date.

for i in range(1,71):
    average=0
    sum=0
    count=1

    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        if(((code== 66)|(code== 67)|(code== 68))&
        ((time>=converted_tz4) & (time<=converted_tz5))):
            sum=sum+value+1
            average=sum/count
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    #print(liste)  
    seri=pd.Series(liste)
    datapatient["Feature22"]=seri
    datapatient["Feature22"]=datapatient["Feature22"].fillna(0)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all 00-06 Activity levels up to that date.

for i in range(1,71):
    average=0
    sum=0
    count=1

    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        if(((code== 69)|(code== 70)|(code== 71))&
        ((time>=converted_tz1) & (time<=converted_tz2))):
            sum=sum+value+1
            average=sum/count
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    #print(liste)  
    seri=pd.Series(liste)
    datapatient["Feature23"]=seri
    datapatient["Feature23"]=datapatient["Feature23"].fillna(0)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#verage of all 06-12 Activity levels up to that date.

for i in range(1,71):
    average=0
    sum=0
    count=1

    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        if(((code== 69)|(code== 70)|(code== 71))&
        ((time>=converted_tz2) & (time<=converted_tz3))):
            sum=sum+value+1
            average=sum/count
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    #print(liste)  
    seri=pd.Series(liste)
    datapatient["Feature24"]=seri
    datapatient["Feature24"]=datapatient["Feature24"].fillna(0)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all 12-18 Activity levels up to that date.

for i in range(1,71):
    average=0
    sum=0
    count=1

    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        if(((code== 69)|(code== 70)|(code== 71))&
        ((time>=converted_tz3) & (time<=converted_tz4))):
            sum=sum+value+1
            average=sum/count
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    #print(liste)  
    seri=pd.Series(liste)
    datapatient["Feature25"]=seri
    datapatient["Feature25"]=datapatient["Feature25"].fillna(0)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all 18-24 Activity levels up to that date.

for i in range(1,71):
    average=0
    sum=0
    count=1

    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    for j in range(len(datapatient)-1):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]
        time=datapatient.loc[j,"Time"]
        if(((code== 69)|(code== 70)|(code== 71))&
        ((time>=converted_tz4) & (time<=converted_tz5))):
            sum=sum+value+1
            average=sum/count
            liste.append(average)
            count=count+1
        else:
            liste.append(liste[len(liste)-1])
    #print(liste)  
    seri=pd.Series(liste)
    datapatient["Feature26"]=seri
    datapatient["Feature26"]=datapatient["Feature26"].fillna(0)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all Food intake levels in the same time zone BMEN

for i in range(1,71):
    avrgb = 0
    avrgM = 0
    avrgE = 0
    avrgN = 0
    sumb = 0
    sumM=0
    sumN=0
    sumE=0
    countb = 1
    countM=1
    countE=1
    countN=1
    countere=1
    counterb=1
    counterm=1
    countern=1

    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]+1
        time=datapatient.loc[j,"Time"]
        if ((code == 66) | (code == 67) | (code == 68)):
            if ((time>=converted_tz1) & (time<=converted_tz2)): #bedtime
                if counterb==1:
                    liste.append(np.nan)
                    sumb = value
                    avrgb = sumb
                    counterb += 1
                    countb += 1
                else:
                    liste.append(avrgb)
                    sumb = sumb + value
                    avrgb = sumb / countb
                    countb += 1
            elif ((time>=converted_tz2) & (time<=converted_tz3)):#mor ning 
                if counterm==1:
                    liste.append(np.nan)
                    sumM = value
                    avrgM = sumM
                    counterm += 1
                    countM +=1
                else:
                    liste.append(avrgM)
                    sumM=sumM + value
                    avrgM =sumM /countM
                    countM +=1
            elif ((time>=converted_tz3) & (time<=converted_tz4)):#evening
                if countere==1:
                    liste.append(np.nan)
                    sumE = value
                    avrgE = sumE
                    countere +=1
                    countE +=1
                else:
                    liste.append(avrgE)
                    sumE = sumE + value
                    avrgE = sumE /countE
                    countE +=1
            elif  ((time>=converted_tz4) & (time<=converted_tz5)): # night
                if countern==1:
                    sumN = value
                    avrgN = sumN
                    liste.append(np.nan)
                    countern += 1
                    countN +=1
                else:
                    liste.append(avrgN)
                    sumN = sumN + value
                    avrgN = sumN / countN 
                    countN +=1
        else:
            liste.append(np.nan)
   # print(liste)
    seri=pd.Series(liste)
    datapatient["Feature27_BMEN"]=seri
    datapatient["Feature27_BMEN"]=datapatient["Feature27_BMEN"].fillna(0)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all Food intake levels in the same time zone WorkNonWork
for i in range(1,71):
    avrgb = 0
    avrgM = 0

    sumb = 0
    sumM=0

    countb = 1
    countM=1

    counterb=1
    counterm=1

    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]+1
        time=datapatient.loc[j,"Time"]
        if ((code == 66) | (code == 67) | (code == 68)):
            if ((time>=converted_tz2) & (time<=converted_tz4)): #work
                if counterb==1:
                    liste.append(np.nan)
                    sumb = value
                    avrgb = sumb
                    counterb += 1
                    countb += 1
                else:
                    liste.append(avrgb)
                    sumb = sumb + value
                    avrgb = sumb / countb
                    countb += 1
            elif ((time>=converted_tz1)  & (time<=converted_tz2)) | ((time >= converted_tz4) & (time<= converted_tz5)):#nonwork
                if counterm==1:
                    liste.append(np.nan)
                    sumM = value
                    avrgM = sumM
                    counterm += 1
                    countM +=1
                else:
                    liste.append(avrgM)
                    sumM=sumM + value
                    avrgM =sumM /countM
                    countM +=1
        else:
            liste.append(np.nan)
   # print(liste)
    seri=pd.Series(liste)
    datapatient["Feature27_WorkNonWork"]=seri
    datapatient["Feature27_WorkNonWork"]=datapatient["Feature27_WorkNonWork"].fillna(0)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all Activity levels in the same time zone. BMEN
for i in range(1,71):
    avrgb = 0
    avrgM = 0
    avrgE = 0
    avrgN = 0
    sumb = 0
    sumM=0
    sumN=0
    sumE=0
    countb = 1
    countM=1
    countE=1
    countN=1
    countere=1
    counterb=1
    counterm=1
    countern=1

    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]+1
        time=datapatient.loc[j,"Time"]
        if ((code == 69) | (code == 70) | (code == 71)):
            if ((time>=converted_tz1) & (time<=converted_tz2)): #bedtime
                if counterb==1:
                    liste.append(np.nan)
                    sumb = value
                    avrgb = sumb
                    counterb += 1
                    countb += 1
                else:
                    liste.append(avrgb)
                    sumb = sumb + value
                    avrgb = sumb / countb
                    countb += 1
            elif ((time>=converted_tz2) & (time<=converted_tz3)):#mor ning 
                if counterm==1:
                    liste.append(np.nan)
                    sumM = value
                    avrgM = sumM
                    counterm += 1
                    countM +=1
                else:
                    liste.append(avrgM)
                    sumM=sumM + value
                    avrgM =sumM /countM
                    countM +=1
            elif ((time>=converted_tz3) & (time<=converted_tz4)):#evening
                if countere==1:
                    liste.append(np.nan)
                    sumE = value
                    avrgE = sumE
                    countere +=1
                    countE +=1
                else:
                    liste.append(avrgE)
                    sumE = sumE + value
                    avrgE = sumE /countE
                    countE +=1
            elif  ((time>=converted_tz4) & (time<=converted_tz5)): # night
                if countern==1:
                    sumN = value
                    avrgN = sumN
                    liste.append(np.nan)
                    countern += 1
                    countN +=1
                else:
                    liste.append(avrgN)
                    sumN = sumN + value
                    avrgN = sumN / countN 
                    countN +=1
        else:
            liste.append(np.nan)
   # print(liste)
    seri=pd.Series(liste)
    datapatient["Feature28_BMEN"]=seri
    datapatient["Feature28_BMEN"]=datapatient["Feature28_BMEN"].fillna(0)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all Activity levels in the same time zone.WorkNonWorkhr
for i in range(1,71):
    avrgb = 0
    avrgM = 0

    sumb = 0
    sumM=0

    countb = 1
    countM=1

    counterb=1
    counterm=1

    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    #All "Time" column has been converted to Time format.
    datapatient['Time'] = pd.to_datetime(datapatient['Time'], format="%H:%M:%S").dt.time
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Value"]+1
        time=datapatient.loc[j,"Time"]
        if ((code == 69) | (code == 70) | (code == 71)):
            if ((time>=converted_tz2) & (time<=converted_tz4)): #work
                if counterb==1:
                    liste.append(np.nan)
                    sumb = value
                    avrgb = sumb
                    counterb += 1
                    countb += 1
                else:
                    liste.append(avrgb)
                    sumb = sumb + value
                    avrgb = sumb / countb
                    countb += 1
            elif ((time>=converted_tz1)  & (time<=converted_tz2)) | ((time >= converted_tz4) & (time<= converted_tz5)):#nonwork
                if counterm==1:
                    liste.append(np.nan)
                    sumM = value
                    avrgM = sumM
                    counterm += 1
                    countM +=1
                else:
                    liste.append(avrgM)
                    sumM=sumM + value
                    avrgM =sumM /countM
                    countM +=1
        else:
            liste.append(np.nan)
   # print(liste)
    seri=pd.Series(liste)
    datapatient["Feature28_WorkNonWork"]=seri
    datapatient["Feature28_WorkNonWork"]=datapatient["Feature28_WorkNonWork"].fillna(0)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Converting timestamps to date and time

from datetime import datetime

def getdate(timestamp):
    ts = int(timestamp)
    return datetime.utcfromtimestamp(ts)

# %%
#Average of Food Intake in the last 4 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    post_blood=[48,57,59,61,63]
    post_bloodfilter=datapatient["Code"].isin(post_blood)
    datafeature32 = datapatient[post_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]
    
    for date in dates:
        # 4 hours = 240mins. Since the last time is not included, it becomes 241.
        dateRange =pd.date_range(end=date,freq='min',periods=241,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([66,67,68])].Value.mean())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if(code == 59)|(code == 61)|(code == 63)|(code == 48)|(code == 57):

            liste.append(value+1)
        else:
            liste.append(0)
 
    seri=pd.Series(liste)
    datapatient["Feature29"]=seri
    datapatient["Feature29"]=datapatient["Feature29"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of Food Intake in the last 6 hours.
for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    post_blood=[48,57,59,61,63]
    post_bloodfilter=datapatient["Code"].isin(post_blood)
    datafeature32 = datapatient[post_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 6 hours = 360mins. Since the last time is not included, it becomes 361.
        dateRange =pd.date_range(end=date,freq='min',periods=361,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([66,67,68])].Value.mean())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if(code == 59)|(code == 61)|(code == 63)|(code == 48)|(code == 57):

            liste.append(value+1)
        else:
            liste.append(0)

    seri=pd.Series(liste)
    datapatient["Feature30"]=seri
    datapatient["Feature30"]=datapatient["Feature30"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of Food Intake in the last 1.5 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    post_blood=[48,57,59,61,63]
    post_bloodfilter=datapatient["Code"].isin(post_blood)
    datafeature32 = datapatient[post_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 1.5 hours = 90mins. Since the last time is not included, it becomes 91.
        dateRange =pd.date_range(end=date,freq='min',periods=91,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([66,67,68])].Value.mean())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if(code == 59)|(code == 61)|(code == 63)|(code == 48)|(code == 57):

            liste.append(value+1)
        else:
            liste.append(0)

    seri=pd.Series(liste)
    datapatient["Feature31"]=seri
    datapatient["Feature31"]=datapatient["Feature31"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of Food Intake in the last 24 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    post_blood=[48,57,59,61,63]
    post_bloodfilter=datapatient["Code"].isin(post_blood)
    datafeature32 = datapatient[post_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 24 hours = 1440mins. Since the last time is not included, it becomes 1441.
        dateRange =pd.date_range(end=date,freq='min',periods=1441,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([66,67,68])].Value.mean())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if(code == 59)|(code == 61)|(code == 63)|(code == 48)|(code == 57):

            liste.append(value+1)
        else:
            liste.append(0)
 
    seri=pd.Series(liste)
    datapatient["Feature32"]=seri
    datapatient["Feature32"]=datapatient["Feature32"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of Food Intake in the last 2 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    post_blood=[48,57,59,61,63]
    post_bloodfilter=datapatient["Code"].isin(post_blood)
    datafeature32 = datapatient[post_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 2 hours = 120mins. Since the last time is not included, it becomes 121.
        dateRange =pd.date_range(end=date,freq='min',periods=121,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([66,67,68])].Value.mean())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if(code == 59)|(code == 61)|(code == 63)|(code == 48)|(code == 57):

            liste.append(value+1)
        else:
            liste.append(0)

    seri=pd.Series(liste)
    datapatient["Feature33"]=seri
    datapatient["Feature33"]=datapatient["Feature33"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of Food Intake in the last 1 hour.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    post_blood=[48,57,59,61,63]
    post_bloodfilter=datapatient["Code"].isin(post_blood)
    datafeature32 = datapatient[post_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 1 hour = 60mins. Since the last time is not included, it becomes 61.
        dateRange =pd.date_range(end=date,freq='min',periods=61,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([66,67,68])].Value.mean())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if(code == 59)|(code == 61)|(code == 63)|(code == 48)|(code == 57):

            liste.append(value+1)
        else:
            liste.append(0)
            
    seri=pd.Series(liste)
    datapatient["Feature34"]=seri
    datapatient["Feature34"]=datapatient["Feature34"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Time Elapsed since last meal (in hours, rounded down)
import numpy as np

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    food=[66,67,68]
    foodfilter=datapatient["Code"].isin(food)
    datafeature37= datapatient[foodfilter]
    datafeature37["Time_Stamp1"]=datafeature37["Time_Stamp"].shift(1)
    fark=datafeature37["Time_Stamp"]-datafeature37["Time_Stamp1"]

    datapatient["Feature_35"]=round(fark/3600,0)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Feature_35"]
        if(code== 66) | (code == 67)|(code==68):

            liste.append(value)
        else:
            liste.append(liste[len(liste)-1])
 
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature35"]=seri
    datapatient=datapatient.drop("Feature_35",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Time Elapsed since last meal (in min, rounded down)

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    food=[66,67,68]
    foodfilter=datapatient["Code"].isin(food)
    datafeature38= datapatient[foodfilter]
    datafeature38["Time_Stamp1"]=datafeature38["Time_Stamp"].shift(1)
    fark=datafeature38["Time_Stamp"]-datafeature38["Time_Stamp1"]
    datapatient["Feature_36"]=round(fark/60,0)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )  

for i in range(1,71):
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Feature_36"]
        if(code== 66) | (code == 67)|(code==68):

            liste.append(value)
        else:
            liste.append(liste[len(liste)-1])
 
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature36"]=seri
    datapatient=datapatient.drop("Feature_36",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of Regular Insulin Level in the last 6 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 6 hour = 360mins. Since the last time is not included, it becomes 361.
        dateRange =pd.date_range(end=date,freq='min',periods=361,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([33])].Value.mean())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if(((code == 48)|(code == 57)|(code == 58)|(code == 59)|(code == 60)|(code ==61)|(code == 62)|(code == 63)|(code == 64))& (np.isnan(value)==False)):

            liste.append(value)
        else:
            liste.append(liste[len(liste) - 1])
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature37"]=seri
   # datapatient["Feature37"]=datapatient["Feature37"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of NPH Insulin Level in the last 14 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 14 hour = 840mins. Since the last time is not included, it becomes 841.
        dateRange =pd.date_range(end=date,freq='min',periods=841,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([34])].Value.mean())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if(((code == 48)|(code == 57)|(code == 58)|(code == 59)|(code == 60)|(code ==61)|(code == 62)|(code == 63)|(code == 64))& (np.isnan(value)==False)):

            liste.append(value)
        else:
            liste.append(liste[len(liste) - 1])
            
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature38"]=seri
   # datapatient["Feature38"]=datapatient["Feature38"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of Ultralente Insulin Level in the last 24 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 24 hour = 1440mins. Since the last time is not included, it becomes 1441.
        dateRange =pd.date_range(end=date,freq='min',periods=1441,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([35])].Value.mean())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if(((code == 48)|(code == 57)|(code == 58)|(code == 59)|(code == 60)|(code ==61)|(code == 62)|(code == 63)|(code == 64))& (np.isnan(value)==False)):

            liste.append(value)
        else:
            liste.append(liste[len(liste) - 1])
    
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature39"]=seri
   # datapatient["Feature39"]=datapatient["Feature39"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Maximum of Regular insulin in the last 6 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 6 hour = 360mins. Since the last time is not included, it becomes 361.
        dateRange =pd.date_range(end=date,freq='min',periods=361,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([33])].Value.max())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if(((code == 48)|(code == 57)|(code == 58)|(code == 59)|(code == 60)|(code ==61)|(code == 62)|(code == 63)|(code == 64))& (np.isnan(value)==False)):

            liste.append(value)
        else:
            liste.append(liste[len(liste) - 1])
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature40"]=seri
   # datapatient["Feature40"]=datapatient["Feature40"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Maximum of NPH insulin in the last 14 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 14 hour = 840mins. Since the last time is not included, it becomes 841.
        dateRange =pd.date_range(end=date,freq='min',periods=841,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([34])].Value.max())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if(((code == 48)|(code == 57)|(code == 58)|(code == 59)|(code == 60)|(code ==61)|(code == 62)|(code == 63)|(code == 64))& (np.isnan(value)==False)):

            liste.append(value)
        else:
            liste.append(liste[len(liste) - 1])
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature41"]=seri
   # datapatient["Feature41"]=datapatient["Feature41"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Maximum of Ultralente Insulin Level in the last 24 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 24 hour = 1440mins. Since the last time is not included, it becomes 1441.
        dateRange =pd.date_range(end=date,freq='min',periods=1441,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([35])].Value.max())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if(((code == 48)|(code == 57)|(code == 58)|(code == 59)|(code == 60)|(code ==61)|(code == 62)|(code == 63)|(code == 64))& (np.isnan(value)==False)):

            liste.append(value)
        else:
            liste.append(liste[len(liste) - 1])
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature42"]=seri
   # datapatient["Feature42"]=datapatient["Feature42"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Total Activity in the last 2 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 2 hours = 120mins. Since the last time is not included, it becomes 121.
        dateRange =pd.date_range(end=date,freq='min',periods=121,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([69,70,71])].Value.count())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if (code== 48) | (code == 57)|(code== 58) | (code == 59)|(code== 60) | (code == 61)|(code== 62) | (code == 63)|(code== 64):

            liste.append(value)
        else:
            liste.append(0)
 
    seri=pd.Series(liste)
    datapatient["Feature43"]=seri
    datapatient["Feature43"]=datapatient["Feature43"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Total Activity in the last 4 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 4 hours = 240mins. Since the last time is not included, it becomes 241.
        dateRange =pd.date_range(end=date,freq='min',periods=241,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([69,70,71])].Value.count())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if (code== 48) | (code == 57)|(code== 58) | (code == 59)|(code== 60) | (code == 61)|(code== 62) | (code == 63)|(code== 64):

            liste.append(value)
        else:
            liste.append(0)
 
    seri=pd.Series(liste)
    datapatient["Feature44"]=seri
    datapatient["Feature44"]=datapatient["Feature44"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Total Activity in the last 6 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 6 hours = 360mins. Since the last time is not included, it becomes 361.
        dateRange =pd.date_range(end=date,freq='min',periods=361,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([69,70,71])].Value.count())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if (code== 48) | (code == 57)|(code== 58) | (code == 59)|(code== 60) | (code == 61)|(code== 62) | (code == 63)|(code== 64):

            liste.append(value)
        else:
            liste.append(0)

    seri=pd.Series(liste)
    datapatient["Feature45"]=seri
    datapatient["Feature45"]=datapatient["Feature45"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Total Activity in the last 12 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 12 hours = 720mins. Since the last time is not included, it becomes 721.
        dateRange =pd.date_range(end=date,freq='min',periods=721,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([69,70,71])].Value.count())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if (code== 48) | (code == 57)|(code== 58) | (code == 59)|(code== 60) | (code == 61)|(code== 62) | (code == 63)|(code== 64):

            liste.append(value)
        else:
            liste.append(0)

    seri=pd.Series(liste)
    datapatient["Feature46"]=seri
    datapatient["Feature46"]=datapatient["Feature46"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Total Activity in the last 24 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 24 hours = 1440mins. Since the last time is not included, it becomes 1441.
        dateRange =pd.date_range(end=date,freq='min',periods=1441,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([69,70,71])].Value.count())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if (code== 48) | (code == 57)|(code== 58) | (code == 59)|(code== 60) | (code == 61)|(code== 62) | (code == 63)|(code== 64):

            liste.append(value)
        else:
            liste.append(0)
 
    seri=pd.Series(liste)
    datapatient["Feature47"]=seri
    datapatient["Feature47"]=datapatient["Feature47"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average Activity in the last 2 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 2 hours = 120mins. Since the last time is not included, it becomes 121.
        dateRange =pd.date_range(end=date,freq='min',periods=121,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([69,70,71])].Value.mean())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if (code== 48) | (code == 57)|(code== 58) | (code == 59)|(code== 60) | (code == 61)|(code== 62) | (code == 63)|(code== 64):

            liste.append(value+1)
        else:
            liste.append(0)
 
    seri=pd.Series(liste)
    datapatient["Feature48"]=seri
    datapatient["Feature48"]=datapatient["Feature48"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average Activity in the last 4 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 4 hours = 240mins. Since the last time is not included, it becomes 241.
        dateRange =pd.date_range(end=date,freq='min',periods=241,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([69,70,71])].Value.mean())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if (code== 48) | (code == 57)|(code== 58) | (code == 59)|(code== 60) | (code == 61)|(code== 62) | (code == 63)|(code== 64):

            liste.append(value+1)
        else:
            liste.append(0)
 
    seri=pd.Series(liste)
    datapatient["Feature49"]=seri
    datapatient["Feature49"]=datapatient["Feature49"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average Activity in the last 6 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 6 hours = 360mins. Since the last time is not included, it becomes 361.
        dateRange =pd.date_range(end=date,freq='min',periods=361,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([69,70,71])].Value.mean())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if (code== 48) | (code == 57)|(code== 58) | (code == 59)|(code== 60) | (code == 61)|(code== 62) | (code == 63)|(code== 64):

            liste.append(value+1)
        else:
            liste.append(0)

    seri=pd.Series(liste)
    datapatient["Feature50"]=seri
    datapatient["Feature50"]=datapatient["Feature50"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average Activity in the last 12 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 12 hours = 720mins. Since the last time is not included, it becomes 721.
        dateRange =pd.date_range(end=date,freq='min',periods=721,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([69,70,71])].Value.mean())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if (code== 48) | (code == 57)|(code== 58) | (code == 59)|(code== 60) | (code == 61)|(code== 62) | (code == 63)|(code== 64):

            liste.append(value+1)
        else:
            liste.append(0)
 
    seri=pd.Series(liste)
    datapatient["Feature51"]=seri
    datapatient["Feature51"]=datapatient["Feature51"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average Activity in the last 24 hours.

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    full_blood=[48,57,58,59,60,61,62,63,64]
    full_bloodfilter=datapatient["Code"].isin(full_blood)
    datafeature32 = datapatient[full_bloodfilter]
    dates = datafeature32['Time_Stamp'].apply(getdate)

    liste=[]

    for date in dates:
        # 12 hours = 720mins. Since the last time is not included, it becomes 721.
        dateRange =pd.date_range(end=date,freq='min',periods=721,closed="left") 
        xxx=datapatient[datapatient['Time_Stamp'].apply(getdate).isin(dateRange)]
  
        liste.append(xxx[xxx["Code"].isin([69,70,71])].Value.mean())

    seri=pd.Series(liste)
    seri.index=datafeature32.index
    datapatient["Featuresız"]=seri

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

for i in range(1,71):
    liste=[]
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Featuresız"]
        if (code== 48) | (code == 57)|(code== 58) | (code == 59)|(code== 60) | (code == 61)|(code== 62) | (code == 63)|(code== 64):

            liste.append(value+1)
        else:
            liste.append(0)
 
    seri=pd.Series(liste)
    datapatient["Feature52"]=seri
    datapatient["Feature52"]=datapatient["Feature52"].fillna(0)
    datapatient=datapatient.drop("Featuresız",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all pre-supper Blood sugar levels up to that date in the same group 
#(check whether the value is pre- or post- food consumption and categorize accordingly)
#Pre
import pandas as pd
import numpy as np
for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    food=[66,67,68]
    foodfilter=datapatient["Code"].isin(food)
    datafeature54 = datapatient[foodfilter]

    dates = datafeature54['Time_Stamp'].apply(getdate)

    liste=[]
    for date in dates:
        # 8 hour = 480mins. Since the last time is not included, it becomes 481.
        dateRange =pd.date_range(end=date,freq='min',periods=481,closed="left") 
        liste.append(dateRange[0])

    seri=pd.Series(liste)

    presupper=[62]
    presupperfiltre=datapatient["Code"].isin(presupper)
    datafeature55=datapatient[presupperfiltre]

    datesdatafeature55 = datafeature55['Time_Stamp'].apply(getdate)
    datafeature55["Dates"]=datesdatafeature55
    filterfeature55=datafeature55["Dates"].isin(seri)
    datafeature55=datafeature55[filterfeature55]
    datapatient["Feature_53_Pre"]=np.cumsum(datafeature55["Value"]).shift(1)/np.arange(len(datafeature55))

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False ) 
for i in range(1,71):
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Feature_53_Pre"]
        if ((code== 62) & (np.isnan(value)==False))  :

            liste.append(value)
        else:
            liste.append(liste[len(liste) - 1])
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature53_Pre"]=seri
    datapatient=datapatient.drop("Feature_53_Pre",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all pre-supper Blood sugar levels up to that date in the same group 
#(check whether the value is pre- or post- food consumption and categorize accordingly)
#Post within 2 hrs

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name
    food=[66,67,68]
    foodfilter=datapatient["Code"].isin(food)
    datafeature54_1 = datapatient[foodfilter]


    dates = datafeature54_1['Time_Stamp'].apply(getdate)

    liste=[]
    for date in dates:
        # 2 hour = 120mins. Since the last time is not included, it becomes 121.
        dateRange =pd.date_range(start=date,freq='min',periods=121, closed="right") 
        liste.append(dateRange)

    seri=pd.Series(liste)
    listefeature54=[]
    for j in seri:
        for k in j:
            listefeature54.append(k)

    presupper=[62]
    presupperfiltre=datapatient["Code"].isin(presupper)
    datafeature54_2=datapatient[presupperfiltre]

    datesdatafeature54_2 = datafeature54_2['Time_Stamp'].apply(getdate)
    datafeature54_2["Dates"]=(datesdatafeature54_2)

    filterfeature54_2=datafeature54_2["Dates"].isin(listefeature54)
    datafeature54_2=datafeature54_2[filterfeature54_2]
    datapatient["Feature_53_Post"]=np.cumsum(datafeature54_2["Value"]).shift(1)/np.arange(len(datafeature54_2))

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )
for i in range(1,71):
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Feature_53_Post"]
        if ((code== 62)  & (np.isnan(value)==False)) :

            liste.append(value)
        else:
            liste.append(liste[len(liste) - 1])
 
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature53_Post"]=seri
    datapatient=datapatient.drop("Feature_53_Post",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
#Average of all pre-supper Blood sugar levels up to that date in the same group V2 
#(check whether 2 hours has passed after food intake, categorize accordingly).  

for i in range(1,71):
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    datapatient.index=datapatient["Index"]
    del datapatient.index.name

    food=[66,67,68]
    foodfilter=datapatient["Code"].isin(food)
    datafeature54_1b = datapatient[foodfilter]


    dates = datafeature54_1b['Time_Stamp'].apply(getdate)

    liste=[]
    for date in dates:
        # 2 hour = 120mins. Since the last time is not included, it becomes 121.
        dateRange =pd.date_range(start=date,freq='min',periods=121,closed="right") 
        liste.append(dateRange[119])

    seri=pd.Series(liste)

    presupper=[62]
    presupperfiltre=datapatient["Code"].isin(presupper)
    datafeature54_2b=datapatient[presupperfiltre]

    datesdatafeature54_2b = datafeature54_2b['Time_Stamp'].apply(getdate)
    datafeature54_2b["Dates"]=datesdatafeature54_2b
    filterfeature54_2b=datafeature54_2b["Dates"].isin(seri)
    datafeature54_2b=datafeature54_2b[filterfeature54_2b]
    datapatient["Feature_54"]=np.cumsum(datafeature54_2b["Value"]).shift(1)/np.arange(len(datafeature54_2b))

    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False ) 
for i in range(1,71):
    liste=[]
    liste.insert(0,np.nan)
    datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
    for j in range(len(datapatient)):
        code=datapatient.loc[j,"Code"]
        value=datapatient.loc[j,"Feature_54"]
        if ((code== 62) & (np.isnan(value)==False)) :

            liste.append(value)
        else:
            liste.append(liste[len(liste) - 1])
    liste.pop(0)
    seri=pd.Series(liste)
    datapatient["Feature54"]=seri
    datapatient=datapatient.drop("Feature_54",axis=1)
    datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt", index=False )

# %%
for i in range(1,2):
    if i<10:
        datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
        datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\eren\\"+"0"+ str(i) + ".txt", index=False ) 
    else:
        datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
        datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\eren\\"+ str(i) + ".txt", index=False ) 

for i in range(2,71):
    if i<10:
        datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
        datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\eren\\"+"0"+ str(i) + ".txt", index=False, header=None ) 
    else:
        datapatient = pd.read_csv(r"C:\\Users\\Lenovo\\Desktop\\Yeni klasör\\"+ str(i) + ".txt")
        datapatient.to_csv(r"C:\\Users\\Lenovo\\Desktop\\eren\\"+ str(i) + ".txt", index=False, header=None )

# %%
import glob

read_files = glob.glob('C:\\Users\\Lenovo\\Desktop\\eren\\*.txt')

with open('C:\\Users\\Lenovo\\Desktop\\Data_Mining\\70Patients.txt', 'w') as outfile:
    for f in read_files:
        with open(f, 'r') as infile:
            outfile.write(infile.read())
